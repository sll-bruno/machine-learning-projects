# %% [markdown]
# # Introduction to Machine Learning -- MC886
# # Assignment 1 - Linear Models
#
# **Professor:** Marcelo da Silva Reis\
# **PED:** Daniel Gardin Gratti\
# **PAD:** Guilherme Henrique Ichiro Seto Ito

# %%
# Please, enter your name and RA number in the lines below:
print("Bruno Amaral Salles de Moraes", "|", "281129")
print("Student 2", "|", "RA2")
print("Student 3", "|", "RA3") # You may remove this line if you are only 2 students in the group
# Out:
# Bruno Amaral Salles de Moraes | 281129
# Student 2 | RA2
# Student 3 | RA3

# %% [markdown]
# ## Objective

# %% [markdown]
# The objective with this assignment is to explore **Linear Regression** and other
# **Generalized Linear Models** to come up with the best model for the problem.
# Rememberm the goal is not just getting the code running, but gathering a deeper
# understanding on **how** these algorithms work and **why** choosing them in the
# first place.
#
# Every model choice has implicit assumptions about the data, the goal here is to
# understand the underlying assumptions and critically address the limitations
# introduced by them.
#
# ### **Guidelines**
# > Please, read these guidelines carefully
#
# 1. The questions can be answered in English or in Portuguese.
#
# 2. We incentivize visualizing the (training) data to gather insight about the
# problem and the solutions. If you are not sure about an assumption, plot it!
#
# 3. The existing code in this notebook is just a mere reference. You are free to
# change the code as much as you need. You will not be penalized for changing a
# function signature or implementing more functions/classes.
# **Just make the code readable!**
#
# 4. The use of generative AI (ChatGPT, DeepSeek, Llama, GitHub Copilot, etc.) is
# permitted to assist in completing assignments. In such cases the submitted work
# **must** include a statement specifying the models used and, if
# applicable, a transcription of the prompts employed to generate the code
# incorporated into the solution.
# However, using AI to analyse and discuss the results is discouraged.
#
# 5. The final performance of your model is not the main goal, explaining why the
# model has such a performance (it being good or bad) is more important than the
# metric value per se.
#
# 6. Metrics are not detached values, revisit the math behind them to understand
# what they are trying to say about your model.
#
# 7. Do not hesitate in reaching the PED/PAD via Discord.
#
# ---
# ### **Dataset**
# The dataset we will be using is the [Bike Sharing](https://archive.ics.uci.edu/dataset/275/bike+sharing+dataset)
# dataset, an hourly count of rental bikes between 2011 and 2012 in Washington, D.C..
#
# The data has 17379 samples with the following columns
#
# feature | description | data type
# --- | --- | ---
# **instant** | Integer identifier | Integer
# **dteday** | Datetime of the instant | Date
# **season** | The season (Winter, Spring, Summer and Fall) | Categorical
# **yr** | Year (0 for 2011 and 1 for 2012) | Categorical
# **mnth** | The month number | Categorical
# **hr** | The hour number | Categorical
# **holiday** | Whether the day is a holiday or not | Boolean
# **weekday** | The day of the week | Categorical
# **workingday** | If the day is neither a holiday nor a weekend | Boolean
# **weathersit** | Current weather (Clear, Few clouds, Partly cloudy, Cloudy) | Categorical
# **temp** | Temperature in °C | Continuous
# **atemp** | Feeling temperature in °C | Continuous
# **hum** | Humidity in % | Continuous
# **windspeed** | Wind speed in km/h | Continuous
# **casual** | Count of casual users | Integer
# **registered** | Count of registered users | Integer
# **cnt** | Count of total bikes (casual + registered) | Integer
#
# The goal will be inferring the number of rental bikes only using datetime and
# weather information provided in the dataset.

# %%
# Importing the necessary libraries
# Remember to re-visit the Hands-on 1 notebooks to setup your environment
from numpy.typing import NDArray
import numpy as np

import pandas as pd
import random
import seaborn as sns

# This notebook already has some plot examples in matplotlib, but feel free to
# use other libraries (e.g., seaborn, plotly) if you prefer
import matplotlib.pyplot as plt

# To ensure reproducibility, set the random seed to your
# favorite number (e.g., your RA number)
np.random.seed(42)
random.seed(42)

# Do not tune this number to get better results, it is just to ensure that
# we all have the same random numbers and, therefore, the same results
# Re-run the notebook from the beginning (Run All) before submitting to classroom

# %%
# The dataset is available in the classroom assignment, ensure you have downloaded
# it and placed it in the same folder as this notebook

# Load the dataset
df = pd.read_csv("bike_share.csv")

df["dteday"] = pd.to_datetime(df["dteday"])
df.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
# 3        4 2011-01-01       1   0     1   3        0        6           0
# 4        5 2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp  hum  windspeed  casual  registered  cnt
# 0           1  3.28  3.0014   81        0.0       3          13   16
# 1           1  2.34  1.9982   80        0.0       8          32   40
# 2           1  2.34  1.9982   80        0.0       5          27   32
# 3           1  3.28  3.0014   75        0.0       3          10   13
# 4           1  3.28  3.0014   75        0.0       0           1    1

# %% [markdown]
# Note that the data is time-ordered, each sample has a 1 hour gap between each other.
# The idea is to predict future rental count from past data, thus our evaluation
# protocol must respect the temporal order.
# Therefore, we select the first 80% samples to compose the training data, and the
# remaining 20% will be used for testing pourposes.
#
# **Important:** Never take decisions over the test dataset, it must be only used after
# all models are trained (in the Test Evaluation section).
# Any decision made using test information is called [data leakage](https://en.wikipedia.org/wiki/Leakage_(machine_learning)) and will be penalized.

# %%
train_size = int(0.8 * len(df))

train_df = df[:train_size]
test_df = df[train_size:]

# Securing that df will not be used anymore, to avoid mistakes
del df

print("Train set size:", len(train_df))
print("Test set size:", len(test_df))
# Out:
# Train set size: 13903
# Test set size: 3476

# %% [markdown]
# ---
#
# ## **Data Analysis and Preprocessing**

# %% [markdown]
# This part of the assignment aims to analyze the dataset and preprocess
# the data for the models.
#
#
# (0.5 points)
# First, consider possible problems in your dataset:
# - Should you use all the features in the dataset?
# - What features are important, are there missing values in them?
# - Are there outliers in continous features?
# - How should you handle the categorical features?
# - How does the rental count change when features change?
# - Are these feature correlated?
#
# Do not plot any graph for now, just see some statistics (mean, count, data types).
# You can manually explore the dataframe if you want.

# %%
train_df.describe()
# Out:
#             instant                      dteday        season            yr  \
# count  13903.000000                       13903  13903.000000  13903.000000
# mean    6952.000000  2011-10-21 10:31:11.078184      2.263828      0.378192
# min        1.000000         2011-01-01 00:00:00      1.000000      0.000000
# 25%     3476.500000         2011-05-29 00:00:00      1.000000      0.000000
# 50%     6952.000000         2011-10-22 00:00:00      2.000000      0.000000
# 75%    10427.500000         2012-03-15 00:00:00      3.000000      1.000000
# max    13903.000000         2012-08-07 00:00:00      4.000000      1.000000
# std     4013.594731                         NaN      1.036254      0.484953
#
#                mnth            hr       holiday       weekday    workingday  \
# count  13903.000000  13903.000000  13903.000000  13903.000000  13903.000000
# mean       5.650147     11.546573      0.027404      2.999425      0.684457
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%        3.000000      6.000000      0.000000      1.000000      0.000000
# 50%        5.000000     12.000000      0.000000      3.000000      1.000000
# 75%        8.000000     18.000000      0.000000      5.000000      1.000000
# max       12.000000     23.000000      1.000000      6.000000      1.000000
# std        3.218423      6.912235      0.163264      2.005710      0.464749
#
#          weathersit          temp         atemp           hum     windspeed  \
# count  13903.000000  13903.000000  13903.000000  13903.000000  13903.000000
# mean       1.419981     15.460988     15.549146     62.299576     13.004472
# min        1.000000     -7.060000    -16.000000      0.000000      0.000000
# 25%        1.000000      7.980000      5.997800     47.000000      7.001500
# 50%        1.000000     15.500000     15.996800     62.000000     12.998000
# 75%        2.000000     23.020000     24.999200     79.000000     19.001200
# max        4.000000     39.000000     50.000000    100.000000     56.996900
# std        0.644060      9.292659     11.656519     19.819432      8.242555
#
#              casual    registered           cnt
# count  13903.000000  13903.000000  13903.000000
# mean      34.037977    140.601165    174.639143
# min        0.000000      0.000000      1.000000
# 25%        4.000000     31.000000     37.000000
# 50%       15.000000    107.000000    130.000000
# 75%       46.000000    202.000000    258.000000
# max      367.000000    796.000000    957.000000
# std       47.341186    137.512367    166.955414

# %%
train_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13903 entries, 0 to 13902
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     13903 non-null  int64
#  1   dteday      13903 non-null  datetime64[us]
#  2   season      13903 non-null  int64
#  3   yr          13903 non-null  int64
#  4   mnth        13903 non-null  int64
#  5   hr          13903 non-null  int64
#  6   holiday     13903 non-null  int64
#  7   weekday     13903 non-null  int64
#  8   workingday  13903 non-null  int64
#  9   weathersit  13903 non-null  int64
#  10  temp        13903 non-null  float64
#  11  atemp       13903 non-null  float64
#  12  hum         13903 non-null  int64
#  13  windspeed   13903 non-null  float64
#  14  casual      13903 non-null  int64
#  15  registered  13903 non-null  int64
#  16  cnt         13903 non-null  int64
# dtypes: datetime64[us](1), float64(3), int64(13)
# memory usage: 1.8 MB

# %%
train_df.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
# 3        4 2011-01-01       1   0     1   3        0        6           0
# 4        5 2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp  hum  windspeed  casual  registered  cnt
# 0           1  3.28  3.0014   81        0.0       3          13   16
# 1           1  2.34  1.9982   80        0.0       8          32   40
# 2           1  2.34  1.9982   80        0.0       5          27   32
# 3           1  3.28  3.0014   75        0.0       3          10   13
# 4           1  3.28  3.0014   75        0.0       0           1    1

# %% [markdown]
# > **Question:**
# >
# > Which of the previous questions can you properly answer without visualizing the data?
# > What decisions can be made right now?

# %% [markdown]
# Mesmo sem visualizar graficamente os dados, é possível iniciar um análise exploratória para entender a estruturação do dataset, sobretudo na análise de tipos das colunas e presença/ausẽncia de dados nulos. Nesse cenário, ao análisar as descrições do Dataset e visualizar uma pequena amostras dos dados já é possível obter insights interessantes. Pensando nas perguntas, é possível responder algumas delas enquanto outras demandam análises gráficas e de indicadores mais aprofundados para serem respondidas.
#
# - Should you use all the features in the dataset?
#
# Analisando os dados desse modo, algumas features do dataset deveriam ficar de fora do modelo. Inicialmente, as features de tempo das colunas "yr" "mnth" são redundantes em relação ao timestemp "dteday", de modo que a presença delas no dataset não adiciona informações irrelevantes ao treinamento e adicionam multicolinearidade entre features, o que prejudica (muito) o desempenho de modelos lineares que tentam atribuir pesos a features relacionadas entre si. Em modelos que não são prejudicados por multicolinearidade, features com informações redundantes podem dificultar a convergencia (por exemplo, arvores de decisão que dividem o nó ora por ano ou ora por timestamp) e aumentam o custo computacional dos modelos. Por outro lado, o dia da semana em que a bicicleta está sendo alugada pode ser uma feature importante assumindo-se que os alugueis de bicileta são impactados pelo final de semana ou a chegada dele. Além disso, essas features, e outras como "season" e "weekday" ,são categóricas e, antes de serem usadas, deveriam sofrer algum tipo de encoding para não enviesar matemáticamente a saída ao inserir uma ordenação implicita das categorias (0 para Segunda-Feira, 1 para Terça-Feira e etc).
#
# Portanto, não, nem todas as features deveriam ser utilizadas. Além disso, a feature de identificação não carrega nenhum significado associado ao problema e deve ser removida
#
# - What features are important, are there missing values in them?
#
# Com exeção das features redundantes de tempo e de identificação do registro, todas as features parecem, nessa analise, relevantes e impactam o volume de bicicletas sendo alugadas em um dado momento. Não há valores faltantes em nenhuma das colunas, sendo elas totalmente preenchidas
#
# - Are there outliers in continous features?
#
# Dificil responder essa pergunta sem uma análise mais detalhada de indicadores de outliers como IQR ou Z-Score
#
# - How should you handle the categorical features?
#
# Como descrito na primeira pergunta, as colunas "yr" "mnth" e deveriam ser removidas (ou mantidas e removeriamso "dtetday") e "season" e "weekday" devem sofrer One-Hot Encoding. Um caso particular é "wathersit" que pode ser (Clear, Few clouds, Partly cloudy, Cloudy). Essa feature é um tipo de dado que carrega uma ordem implicita, podendo-se assumir que, quanto mais "Cloudy" o clima, menos alugueis de bicicleta terão, portanto, poderiamos manter a feature ordinal ou fazer um one-hot encoding.
#
# - How does the rental count change when features change?
#
# Não é possível responder
#
# - Are these feature correlated?
#
# Sim, as features "yr" "mnth" são correlacionadas com o timestamp "dteday". Além disso, em algum grau, as features que indicam tempo estão correlacionadas com as features de estações do ano. Para o caso da Sensação térmica, essa feature é uma combinação de Temperatura, Humidade e velocidade do vendo, indicando alta correlação entre elas.

# %% [markdown]
# ---
# (1.0 points) Now, explore the raw data, visualize their relationship with the target `cnt`.
# You can use boxplots to understand feature distributions, histograms to observe
# the count frequency, explore the temporal correlation.
#
# There is no minimum/maximum requirements for the exploratory data analysis, plot
# as many graphs as you need to gather information from your problem.
# After plotting, write about your findings, formulate hypothesis about unseen
# patterns and ponder about the data preprocessing step.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.grid()

timestamp = train_df["dteday"] + pd.to_timedelta(train_df['hr'], unit='h')

# Mean count per hour of the day
hourly_counts = train_df.groupby("hr")["cnt"].mean()
ax.plot(hourly_counts.index, hourly_counts.values, marker="o")

ax.set_xlabel("Hour of the Day")
ax.set_ylabel("Count")
ax.set_title("Average Bike Share Count per Hour of the Day")

plt.xticks(hourly_counts.index)

plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
# Other visualizations here, e.g., histograms, boxplots, scatter plots, heatmaps, etc.
# Find the ones that you think are more interesting and relevant to understand the
# data and the problem at hand.

# Configuração da figura com 2 subplots lado a lado
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# 1. Histograma com Curva de Densidade (KDE)
sns.histplot(train_df['cnt'], bins=30, kde=True, ax=axes[0], color='skyblue')
axes[0].set_title('Distribuição da Variável Alvo (cnt)')
axes[0].set_xlabel('Total de Aluguéis (cnt)')
axes[0].set_ylabel('Frequência')

# 2. Boxplot
sns.boxplot(x=train_df['cnt'], ax=axes[1], color='lightgreen')
axes[1].set_title('Boxplot da Variável Alvo (cnt)')
axes[1].set_xlabel('Total de Aluguéis (cnt)')

plt.tight_layout()
plt.show()

# Imprimindo algumas estatísticas descritivas relevantes para complementar a análise
print("Estatísticas Descritivas de 'cnt':")
print(train_df['cnt'].describe())
print(f"Assimetria (Skewness): {train_df['cnt'].skew():.2f}")
# Out:
# Estatísticas Descritivas de 'cnt':
# count    13903.000000
# mean       174.639143
# std        166.955414
# min          1.000000
# 25%         37.000000
# 50%        130.000000
# 75%        258.000000
# max        957.000000
# Name: cnt, dtype: float64
# Assimetria (Skewness): 1.28

# %%
# Configuração de estilo do gráfico
sns.set_theme(style="whitegrid")

# Criando figura com 4 gráficos (2 linhas e 2 colunas) 
fig, axes = plt.subplots(2, 2, figsize=(18, 12))

# ---------------------------------------------------------
# 1. Contagem de Aluguéis por Hora (Dia Útil vs FDS/Feriado)
# ---------------------------------------------------------
sns.lineplot(data=train_df, x='hr', y='cnt', hue='workingday', palette='Set1', ax=axes[0, 0])

axes[0, 0].set_title('Média de Aluguéis ao longo do Dia', fontsize=14)
axes[0, 0].set_xlabel('Hora do Dia (0-23)')
axes[0, 0].set_ylabel('Média de Aluguéis (cnt)')
axes[0, 0].set_xticks(range(0, 24))
axes[0, 0].legend(title='workingday (1 = Sim, 0 = Não)')

# ---------------------------------------------------------
# 2. Dia da Semana x Média de Aluguéis
# ---------------------------------------------------------
# Mapeando os dias para nomes (opcional, assumindo 0 como Domingo)
dias_semana = ['Dom', 'Seg', 'Ter', 'Qua', 'Qui', 'Sex', 'Sáb']
sns.barplot(data=train_df, x='weekday', y='cnt', palette='Set3', ax=axes[0, 1], errorbar=None)
axes[0, 1].set_title('Média de Aluguéis por Dia da Semana', fontsize=14)
axes[0, 1].set_xlabel('Dia da Semana')
axes[0, 1].set_ylabel('Média de Aluguéis (cnt)')
# Substituindo os números de 0 a 6 pelos nomes dos dias
axes[0, 1].set_xticks(range(7))
axes[0, 1].set_xticklabels(dias_semana)

# ---------------------------------------------------------
# 3. Distribuição de Aluguéis por Estação do Ano
# ---------------------------------------------------------
sns.boxplot(data=train_df, x='season', y='cnt', palette='pastel', ax=axes[1, 0])
axes[1, 0].set_title('Distribuição de Aluguéis por Estação do Ano', fontsize=14)
axes[1, 0].set_xlabel('Estação (1: Inverno, 2: Primavera, 3: Verão, 4: Outono)')
axes[1, 0].set_ylabel('Total de Aluguéis (cnt)')

# ---------------------------------------------------------
# 4. Média de Aluguéis por Mês com Faixas de Estações
# ---------------------------------------------------------
# Como o Seaborn barplot categoriza o eixo X, os índices dos meses vão de 0 (Jan) a 11 (Dez)
sns.barplot(data=train_df, x='mnth', y='cnt', color='gray', ax=axes[1, 1], errorbar=None, zorder=2)
axes[1, 1].set_title('Média de Aluguéis por Mês e Relação com Estações', fontsize=14)
axes[1, 1].set_xlabel('Mês (1 a 12)')
axes[1, 1].set_ylabel('Média de Aluguéis (cnt)')

# Adicionando as faixas coloridas para as estações no fundo (zorder=1 fica atrás das barras zorder=2)
# Nota: Os meses 1, 2, 3 equivalem aos índices 0, 1, 2 no eixo X do barplot
axes[1, 1].axvspan(-0.5, 2.5, color='blue', alpha=0.5, label='1: Inverno', zorder=1)
axes[1, 1].axvspan(2.5, 5.5, color='green', alpha=0.5, label='2: Primavera', zorder=1)
axes[1, 1].axvspan(5.5, 8.5, color='orange', alpha=0.5, label='3: Verão', zorder=1)
axes[1, 1].axvspan(8.5, 11.5, color='brown', alpha=0.5, label='4: Outono', zorder=1)

# Move a legenda para fora do gráfico para não sobrepor as barras
axes[1, 1].legend(title='Estações (Season)', loc='upper left', bbox_to_anchor=(1, 1))

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_18426/1971726499.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=train_df, x='weekday', y='cnt', palette='Set3', ax=axes[0, 1], errorbar=None)
# /tmp/ipykernel_18426/1971726499.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=train_df, x='season', y='cnt', palette='pastel', ax=axes[1, 0])

# %%
# Criando figura com 4 subplots (2 linhas, 2 colunas)
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# 1. Boxplot: Como a 'weathersit' (Situação climática) afeta a contagem
# 1-Limpo, 2-Nublado, 3-Chuva/Neve leve, 4-Tempestade/Neve forte
sns.boxplot(data=train_df, x='weathersit', y='cnt', palette='Set2', ax=axes[0, 0])
axes[0, 0].set_title('Impacto da Situação Climática')
axes[0, 0].set_xlabel('Clima (1: Bom -> 4: Terrível)')
axes[0, 0].set_ylabel('Total de Aluguéis (cnt)')

# 2. Scatter plot: Temperatura vs Contagem
# Usando alpha para ver a densidade dos pontos
sns.scatterplot(data=train_df, x='temp', y='cnt', alpha=0.3, color='orange', edgecolor=None, ax=axes[0, 1])
axes[0, 1].set_title('Temperatura vs Total de Aluguéis')
axes[0, 1].set_xlabel('Temperatura (°C)')
axes[0, 1].set_ylabel('Total de Aluguéis (cnt)')

# 3. Scatter plot: Sensação Térmica vs Contagem
sns.scatterplot(data=train_df, x='atemp', y='cnt', alpha=0.3, color='red', edgecolor=None, ax=axes[1, 0])
axes[1, 0].set_title('Sensação Térmica vs Total de Aluguéis')
axes[1, 0].set_xlabel('Sensação Térmica (°C)')
axes[1, 0].set_ylabel('Total de Aluguéis (cnt)')

# 4. Scatter plot: Umidade vs Contagem
sns.scatterplot(data=train_df, x='hum', y='cnt', alpha=0.3, color='blue', edgecolor=None, ax=axes[1, 1])
axes[1, 1].set_title('Umidade vs Total de Aluguéis')
axes[1, 1].set_xlabel('Umidade (%)')
axes[1, 1].set_ylabel('Total de Aluguéis (cnt)')

plt.tight_layout()
plt.show() # Você vai notar que temp e atemp parecem praticamente idênticos visualmente.
# Out:
# /tmp/ipykernel_18426/1709296749.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=train_df, x='weathersit', y='cnt', palette='Set2', ax=axes[0, 0])

# %%
# Selecionando apenas as variáveis numéricas (contínuas) de maior interesse
numericas = ['temp', 'atemp', 'hum', 'windspeed', 'cnt']

# 1. Matriz de Correlação (Heatmap)
plt.figure(figsize=(8, 6))
correlacao = train_df[numericas].corr()

# Plotando o Heatmap
sns.heatmap(correlacao, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5, vmin=-1, vmax=1)
plt.title('Matriz de Correlação (Variáveis Contínuas)', fontsize=14)
plt.show()

# 2. Pairplot ("Todos contra todos")
# Isso cria um grid de dispersão onde na diagonal ficam descritas as distribuições (histogramas)
# e nos outros eixos fica a relação bivariada
print("Gerando Pairplot, isso leva alguns instantes...")
sns.pairplot(train_df[numericas], diag_kind='kde', plot_kws={'alpha': 0.2, 's': 15})
# Para o pairplot usar a própria plt não há necessidade de figure
plt.suptitle('Pairplot: Relação entre as Variáveis Contínuas Principais', y=1.02, fontsize=16)
plt.show()
# Out:
# Gerando Pairplot, isso leva alguns instantes...

# %%
# 1. Selecionando as variáveis que realmente são categóricas para o One-Hot Encoding
# Variáveis como yr, holiday e workingday já são binárias (0 e 1), deixamos de fora do get_dummies
vars_categoricas = ['season', 'mnth', 'hr', 'weekday', 'weathersit']
# 2. Aplicando o One-Hot Encoding (isso já será útil como base para seu preprocess_data!)
# O drop_first=True evita colinearidade perfeita gerando k-1 colunas para k categorias (dummy trap)
df_ohe = pd.get_dummies(train_df, columns=vars_categoricas, drop_first=True)
# Lembre-se que devemos remover as features vazadas e IDs antes da análise final
vars_remover = ['casual', 'registered', 'instant', 'dteday', 'atemp']
df_ohe_limpo = df_ohe.drop(columns=[col for col in vars_remover if col in df_ohe.columns])
# 3. Calculando a Matriz de Correlação de TODAS as variáveis em relação à variável alvo 'cnt'
# E ordenando para ver os maiores impactos positivos e os maiores impactos negativos
correlacao_com_alvo = df_ohe_limpo.corr()['cnt'].sort_values(ascending=False)
# Vamos remover a linha do próprio 'cnt' (sempre será 1.0)
correlacao_com_alvo = correlacao_com_alvo.drop('cnt')
# 4. Gerando um Barplot Visual do Impacto
plt.figure(figsize=(12, 14))
# Colorindo de verde as correlações positivas e vermelho as negativas
cores = ['#2ca02c' if valor > 0 else '#d62728' for valor in correlacao_com_alvo.values]
sns.barplot(x=correlacao_com_alvo.values, y=correlacao_com_alvo.index, palette=cores, orient='h')
plt.title('Impacto (Correlação) das Variáveis e Categorias OHE sobre o Total de Aluguéis (cnt)', fontsize=15)
plt.xlabel('Coeficiente de Correlação de Pearson')
plt.ylabel('Features (Pré-processadas via OHE)')
# Linha zero para facilitar visualização
plt.axvline(x=0, color='black', linewidth=1)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_18426/3862919924.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=correlacao_com_alvo.values, y=correlacao_com_alvo.index, palette=cores, orient='h')

# %% [markdown]
# > **Question:**
# >
# > How did the visualization help in understanding the data?
# > Which questions were answered and what hypothesis are left to be tested?
# >
# > Have you decided to remove some feature from the dataset? Why?

# %% [markdown]
# Visualizando de forma gráfica os dados, é possível responder algumas das dúvidas e questionamentos levantados na análise não gráfica, sobretudo no que tange a correlação entre as features e importância, analisaremos caso a caso:
#
# 1- Análise temporal
#
# A fim de entender a relação entre as features de caracter temporal, plotamos os gráficos da media de alugueis de bicicleta pela hora do dia (para dias úteis e não úteis), dias da semana, mês e estação do ano. No primeiro caso, fica claro a relação entre a hora do dia em que se aluga a bicicleta. Para dias úteis, temos duas elevações em "cnt" para o período das 8hrs da manha e 17/18hrs da tarde, o que pode explicaar pessoas cujo uso da bicicleta é deslocamento pendular para ir e voltar do trabalho, já para dias não úteis, o aumento dos alugueis se dá nos períodos do meio da tarde, momento de passeio e lazer. Desse modo, fica claro que essa é uma feature de grande importância para entender o comportamento dos alugueis. Analisando apenas os dias da semana, verifica-se que, na média, os alugueis se mantém relativamente constantes ao longo de toda a semana
#
# Nos dois gráficos de baixo, temos a visão em função do mês e da estação do ano. Aqui, é possível ver claramente o impacto da estação do ano no aluguel: para os períodos de junho/julho, há um grande aumento dos alugueis em função da primavera/verão, momento de clima mais agradável para realização de atividades ao ar livre. Já no período de inverno/outono, a tendência se inverte, possívelmente devido ao clima frio.
#
# ![image.png](attachment:image.png)
#
# Nesse gráfico, temos duas features que representam, em partes, a mesma informação e se correlacionam entre si por que Season é uma feature derivada 100% de mnth. A dependência linear gera prejuizos para converfencia do modelo com uma matriz singular. Escolheremos aqui a que tem maior granularidade e removeremos "season" para deixar "mnth".
#
# 2 - Análise das features climáticas
#
# A variável "weathersit" atua como métrica de "qualidade do clima". Se weathersit = 4/Very Cloud, o aluguel de bicicletas diminui muito, o que pode explicar por que no inverno diminui-se tanto a quantidade de alugueis. Além disso, podemos observar claramente a relação entre quantidade de alugueis e a temperatura, mas, pela matriz de correlação, vemos que existe alta correlação entre atemp e temp, que representam temperatura do termometro e sensação térmica. Além disso, a sensação térmica é calculada como combinação linear de "temp", "hum" e "windspeed", que é exatamente o que o modelo linear faz. Desse modo, pra evitar a multicolinearidade, removeremos "atemp"
#
# 3 - Outros
#
# Para as features categóricas faltantes (hr,weekday, "mnth" e weatersit) realizaremos One-Hot encoding.
# Além disso, nosso target final (cnc) é a soma de "casual" e "registered". Mantê-los seria vazar dados para o modelo, logo, removeremos do dataset.
#
# Features que serão removidas: "registered", "casual","atemp", "dteday", "season" e "instant" (identificador). Por fim, separaremos o target "cnc" do dataset final, para ser usado como label
# Features que sofreram One-Hot Encoding: ['mnth','year', 'hr', 'weekday', 'weathersit']
# Feature Nova: "day" incremental criada a partir de "dteday"

# %% [markdown]
# ----
# ### **Preprocessing**
# (1.0 point) Now that you have a deeper insight about the problem, let's preprocess
# the raw data with the necessary transformations and turn the data into an array,
# ready to be fed into a model.
#
# Create a function `preprocess_data` and make all required transformation, the
# output must be a tuple (X, y) of numpy arrays, where X has shape (n_samples, n_features)
# and y is a column array of shape (n_samples,).
#
# Note that the distributions on the features in the test set may not coincide
# with the ones in the train set, your preprocessing must take that into account
# without peeking at test samples.

# %%
def preprocess_data(df: pd.DataFrame) -> tuple[NDArray[np.float64], NDArray[np.float64]]:
    
    data = df.copy()

    y = data['cnt']

    print("Informações sobre o target Y")
    print(y.info())
    print("------------------------")
    
    y = y.to_numpy(np.float64)

    cols_to_drop = ['casual', 'registered', 'dteday', 'instant', 'atemp', 'season', 'cnt']
    categoric_cols = ['mnth','yr', 'hr', 'weekday', 'weathersit']

    data_zero = train_df['dteday'].min()
    data['day'] = (pd.to_datetime(data['dteday']) - data_zero).dt.days
    
    data.drop(columns=cols_to_drop, inplace=True)

    data = pd.get_dummies(data, columns=categoric_cols, drop_first=True, dtype=float)
    
    print("Informações sobre o dataset X")
    print(data.info())
    print("------------------------")
    
    X = data.to_numpy(np.float64)

    return X,y

# %% [markdown]
# ---
#
# ## **Linear Regression**

# %% [markdown]
# Linear regression is a simple model that assumes a linear relationship between
# the observed features and the target.
# Specifically, given an observation $(x_1, x_2, \dots, x_n)$, we assume there exist
# a set of weights $\beta_0, \beta_1, \beta_2, \dots, \beta_n$ such that
#
# $$y \approx \beta_0 + \beta_1 x_1 + \beta_2 x_2 + \dots + \beta_n x_n.$$
#
# Each weight $\beta_i$ measures the marginal contribution of $x_i$ to the
# prediction while keeping other variables fixed.
# The model assumes additive effects, meaning the influence of multiple variables
# is the sum of their individual contributions unless interaction terms are
# explicitly included.
#
# For example, if raining decreases the rental count, but summer increases it, a summer
# rainy day contribution is no different than the contribution of rainy plus the
# contribution of summer.
#
# We can estimate the weights $\beta_i$ by measuring a discrepancy score between
# predicted values $\hat{y}$ obtained withsome weight $\beta$ and the ground-truth
# value $y$, and minimizing this score.
#
# A natural way to achieve this is by defining a distance between targets that is
# differentiable. However, choosing a distance that is statistical relevant is not
# trivial. Instead, we could measure what is the probability that, when given
# a sample $x$ and a current weight $\beta$, the ground-truth $y$ is observed, *i.e.*
#
# $$p(y \mid x, \beta).$$
#
# This measures what is the probability of the ground-truth given that the model
# with weights $\beta$ is the true estimator.
#
# If we tweak the weights $\beta$ so that the probability of all ground-truths is
# maximized, we obtain a well-fit model.
# This is achieved by the likelihood function, under the assumption of independent
# samples in the dataset.
#
# $$\mathcal{L}(\beta) = \prod_{i=1}^n p(y^i \mid x^i, \beta).$$
#
# Indicating that a estimator $\beta$ is only good if the ground-truth probabilities
# are high across all the samples. As this criteria can be very small due to the
# multiplication of small quantities, a common trick is to use the log likelihood
# function instead, using the log properties,
#
# $$\log \mathcal{L}(\beta) = \sum_{i=1}^n \log p(y^i \mid x^i, \beta),$$
# and then minimizing $-\log \mathcal{L}(\beta)$.
#
# This method is called Maximum Likelihood Estimation (MLE) and it is a very commonly
# used estimator in Machine Learning, as we are going to see.
#
# ### **Gaussian assumption**
# We cannot directly measure $p(y \mid x, \beta)$ at the moment, as we do not have
# a probability distribution that links $y$ with $x$ and $\beta$ yet, but a
# deterministic relationship (linear).
#
# To introduce this probabilistic aspect, we can suppose that the approximation
# between the ground-truth $y$ and the linear term $\hat{y} = \beta_0 + \beta_1 x_1 + \dots$
# is only wrong by an unpredictable "error" $\epsilon$, also called a *residual*.
# A common way of introducing this error is by supposing that $\epsilon$ comes from
# a zero-centered normal (or Gaussian) distribution,
# *i.e.* $\epsilon \sim \mathcal{N}(0, \sigma^2)$.
#
# The relationship between $y$, $x$ and $\beta$ are now intermediated by $\epsilon$,
#
# $$y = \beta_0 + \beta_1 x_1 + \beta_2 x_2 + \dots + \beta_n x_n + \epsilon.$$
#
# This makes $y$ to be a random variable centered at our linear predicition, deviated
# by a random quantity, with fixed standard deviation $\sigma$ (homoscedastic).
# This assumption is called **Gaussian assumption**, and has interesting properties
# that intersect with the Ordinary Least Squares method, including the criterion.
#
# With this assumption, we can measure $p(y \mid x, \beta)$ directly using the
# Normal probability distribution function
#
# $$p(y \mid x, \beta) = \frac{1}{\sqrt{2\pi\sigma^2}} \exp\left(- \frac{(y - x^T\beta)^2}{2\sigma^2}\right),$$
#
# $$\log p(y \mid x, \beta) =  - \frac{(y - x^T\beta)^2}{2\sigma^2} - \log(\sqrt{2\pi\sigma^2}).$$
#
# Thus, minimizing $-\log \mathcal{L}(\beta)$, yield to
#
# $$-\log \mathcal{L}(\beta) \propto \sum_{i=1}^n (y^i - {x^i}^T\beta)^2 = \sum_{i=1}^n (y^i - \hat{y}^i)^2 $$
#
# Which is equivalent to the Mean Squared Error (MSE) criterion.
#
# ### **Implementation**
#
# (0.5 points) Under the statistical lens of Linear Regression, we have also
# derived the same loss function as ordinary least squares method. Now it's time to
# implement the `fit` method using **gradient descent** without using any machine
# learning library.
#
#
# Also, complete the following metric functions with their implementations and run
# your model for different learning rates

# %%
def mse(y_true: NDArray[np.float64], y_pred: NDArray[np.float64]) -> float:

    n = y_pred.shape[0]

    #Garante que y_pred e Y_true tem tamanhos iguais
    assert n == y_true.shape[0], "y_pred e y_true tem tamanhos diferentes"

    return np.mean((y_true - y_pred) ** 2)

def r2_score(y_true: NDArray[np.float64], y_pred: NDArray[np.float64]) -> float:
    
    n = y_pred.shape[0]

    #Garante que y_pred e Y_true tem tamanhos iguais
    assert n == y_true.shape[0], "y_pred e y_true tem tamanhos diferentes"

    ss_res = np.sum((y_true - y_pred) ** 2)

    media_y = np.mean(y_true)
    ss_tot = np.sum((y_true - media_y)**2)

    r2 = 1 - (ss_res / ss_tot)
    return r2

def mae(y_true: NDArray[np.float64], y_pred: NDArray[np.float64]) -> float:
    
    n = y_pred.shape[0]

    #Garante que y_pred e Y_true tem tamanhos iguais
    assert n == y_true.shape[0], "y_pred e y_true tem tamanhos diferentes"

    return np.mean(np.abs(y_true - y_pred))

def mape(y_true: NDArray[np.float64], y_pred: NDArray[np.float64]) -> float:
    n = y_pred.shape[0]

    # Garante que y_pred e y_true tem tamanhos iguais
    assert n == y_true.shape[0], "y_pred e y_true tem tamanhos diferentes"

    epsilon = 1e-8 
    return np.mean(np.abs((y_true - y_pred) / (y_true + epsilon)))



# You can implement other metrics if you want, for example
# - Mean Absolute Percentage Error (MAPE)
# - Root Mean Squared Error (RMSE)
# - Explained Variance Score
# - etc.

class LinearRegression:
    def __init__(
        self,
        learning_rate: float = 0.01,
        n_iterations: int = 1000,
    ) -> None:
        self.learning_rate = learning_rate
        self.n_iterations = n_iterations
        self.weights: NDArray[np.float64] | None = None
        self.bias: float | None = None

    def fit(self, X: NDArray[np.float64], y: NDArray[np.float64]) -> None:
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0.0

        print(f"Iniciando treinamento( learning_rate = {self.learning_rate} ):")
        for i in range(self.n_iterations):

            #Calcula gradiente
            dw, db = self._grad_cost(X,y)

            # Atualiza pesos
            self.weights -= (self.learning_rate * dw)
            self.bias -= (self.learning_rate * db)

            if (i % 100 == 0): 
                loss = mse(y, self.predict(X))

                print(f"   - iteration: {i} | loss (MSE) = {loss:.3f} | bias = {self.bias:.3f}")

        print("Treinamento Finalizado")
    
    def _grad_cost(self, X: NDArray[np.float64], y: NDArray[np.float64]) -> tuple[NDArray[np.float64], float]:
        #Cálculo do gradiente do MSE 
        #   O gradiente do MSE é dado por:
        #   dW = 1/m * sum i -> m (err * x)
        
        n_samples, n_features = X.shape
        y_pred = self.predict(X)
        err = y_pred - y

        dw = 1/n_samples * (np.dot(X.T, err))
        db = 1/n_samples * np.sum(err)

        return dw, db


    def predict(self, X: NDArray[np.float64]) -> NDArray[np.float64]:
        assert self.weights is not None and self.bias is not None, "Model is not trained yet"

        return X @ self.weights + self.bias # Dot product

# %%
def plot_results(lrs: list[float], performances: dict[str, list[float]]) -> None:
    n_metrics = len(performances)

    fig, ax = plt.subplots(figsize=(5 * n_metrics, 5), ncols=n_metrics)

    for i, (metric_name, metric_values) in enumerate(performances.items()):
        ax[i].plot(lrs, metric_values, marker="o")
        ax[i].set_xlabel("Learning Rate")
        ax[i].set_title(metric_name)
        ax[i].grid(True)
    
        ax[i].set_xscale("log")

    plt.tight_layout()
    plt.show()

# %%
X, y = preprocess_data(train_df)
# Out:
# Informações sobre o target Y
# <class 'pandas.Series'>
# RangeIndex: 13903 entries, 0 to 13902
# Series name: cnt
# Non-Null Count  Dtype
# --------------  -----
# 13903 non-null  int64
# dtypes: int64(1)
# memory usage: 108.7 KB
# None
# ------------------------
# Informações sobre o dataset X
# <class 'pandas.DataFrame'>
# RangeIndex: 13903 entries, 0 to 13902
# Data columns (total 50 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   holiday       13903 non-null  int64
#  1   workingday    13903 non-null  int64
#  2   temp          13903 non-null  float64
#  3   hum           13903 non-null  int64
#  4   windspeed     13903 non-null  float64
#  5   day           13903 non-null  int64
#  6   mnth_2        13903 non-null  float64
#  7   mnth_3        13903 non-null  float64
#  8   mnth_4        13903 non-null  float64
#  9   mnth_5        13903 non-null  float64
#  10  mnth_6        13903 non-null  float64
#  11  mnth_7        13903 non-null  float64
#  12  mnth_8        13903 non-null  float64
#  13  mnth_9        13903 non-null  float64
#  14  mnth_10       13903 non-null  float64
#  15  mnth_11       13903 non-null  float64
#  16  mnth_12       13903 non-null  float64
#  17  yr_1          13903 non-null  float64
#  18  hr_1          13903 non-null  float64
#  19  hr_2          13903 non-null  float64
#  20  hr_3          13903 non-null  float64
#  21  hr_4          13903 non-null  float64
#  22  hr_5          13903 non-null  float64
#  23  hr_6          13903 non-null  float64
#  24  hr_7          13903 non-null  float64
#  25  hr_8          13903 non-null  float64
#  26  hr_9          13903 non-null  float64
#  27  hr_10         13903 non-null  float64
#  28  hr_11         13903 non-null  float64
#  29  hr_12         13903 non-null  float64
#  30  hr_13         13903 non-null  float64
#  31  hr_14         13903 non-null  float64
#  32  hr_15         13903 non-null  float64
#  33  hr_16         13903 non-null  float64
#  34  hr_17         13903 non-null  float64
#  35  hr_18         13903 non-null  float64
#  36  hr_19         13903 non-null  float64
#  37  hr_20         13903 non-null  float64
#  38  hr_21         13903 non-null  float64
#  39  hr_22         13903 non-null  float64
#  40  hr_23         13903 non-null  float64
#  41  weekday_1     13903 non-null  float64
#  42  weekday_2     13903 non-null  float64
#  43  weekday_3     13903 non-null  float64
#  44  weekday_4     13903 non-null  float64
#  45  weekday_5     13903 non-null  float64
#  46  weekday_6     13903 non-null  float64
#  47  weathersit_2  13903 non-null  float64
#  48  weathersit_3  13903 non-null  float64
#  49  weathersit_4  13903 non-null  float64
# dtypes: float64(46), int64(4)
# memory usage: 5.3 MB
# None
# ------------------------

# %%
# You can experiment with a pre-defined set of learning rates or
# with a range of learning rates (e.g. logarithmically spaced)
lrs = np.logspace(-12, -1, num=12)

print(f"Learning Rates de Treinamento = {lrs}")

performances = {
    "mse": [],
    "r2_score": [],
    "mae": [],
    "mape": [],
    # Add other metrics here if you implemented them
}

for lr in lrs:
    model = LinearRegression(learning_rate=lr, n_iterations=10000)
    model.fit(X, y)
    y_pred = model.predict(X)

    mse_score = mse(y, y_pred)
    r2 = r2_score(y, y_pred)
    mae_score = mae(y, y_pred)
    mape_score = mape(y,y_pred)

    performances["mse"].append(mse_score)
    performances["r2_score"].append(r2)
    performances["mae"].append(mae_score)
    performances["mape"].append(mape_score)

plot_results(lrs, performances)
# Out:
# Learning Rates de Treinamento = [1.e-12 1.e-11 1.e-10 1.e-09 1.e-08 1.e-07 1.e-06 1.e-05 1.e-04 1.e-03
#  1.e-02 1.e-01]
# Iniciando treinamento( learning_rate = 1e-12 ):
#    - iteration: 0 | loss (MSE) = 58370.935 | bias = 0.000
#    - iteration: 100 | loss (MSE) = 58370.912 | bias = 0.000
#    - iteration: 200 | loss (MSE) = 58370.890 | bias = 0.000
#    - iteration: 300 | loss (MSE) = 58370.867 | bias = 0.000
#    - iteration: 400 | loss (MSE) = 58370.845 | bias = 0.000
#    - iteration: 500 | loss (MSE) = 58370.822 | bias = 0.000
#    - iteration: 600 | loss (MSE) = 58370.799 | bias = 0.000
#    - iteration: 700 | loss (MSE) = 58370.777 | bias = 0.000
#    - iteration: 800 | loss (MSE) = 58370.754 | bias = 0.000
#    - iteration: 900 | loss (MSE) = 58370.731 | bias = 0.000
#    - iteration: 1000 | loss (MSE) = 58370.709 | bias = 0.000
#    - iteration: 1100 | loss (MSE) = 58370.686 | bias = 0.000
#    - iteration: 1200 | loss (MSE) = 58370.664 | bias = 0.000
#    - iteration: 1300 | loss (MSE) = 58370.641 | bias = 0.000
#    - iteration: 1400 | loss (MSE) = 58370.618 | bias = 0.000
#    - iteration: 1500 | loss (MSE) = 58370.596 | bias = 0.000
#    - iteration: 1600 | loss (MSE) = 58370.573 | bias = 0.000
#    - iteration: 1700 | loss (MSE) = 58370.550 | bias = 0.000
#    - iteration: 1800 | loss (MSE) = 58370.528 | bias = 0.000
#    - iteration: 1900 | loss (MSE) = 58370.505 | bias = 0.000
#    - iteration: 2000 | loss (MSE) = 58370.483 | bias = 0.000
#    - iteration: 2100 | loss (MSE) = 58370.460 | bias = 0.000
#    - iteration: 2200 | loss (MSE) = 58370.437 | bias = 0.000
#    - iteration: 2300 | loss (MSE) = 58370.415 | bias = 0.000
#    - iteration: 2400 | loss (MSE) = 58370.392 | bias = 0.000
#    - iteration: 2500 | loss (MSE) = 58370.369 | bias = 0.000
#    - iteration: 2600 | loss (MSE) = 58370.347 | bias = 0.000
#    - iteration: 2700 | loss (MSE) = 58370.324 | bias = 0.000
#    - iteration: 2800 | loss (MSE) = 58370.302 | bias = 0.000
#    - iteration: 2900 | loss (MSE) = 58370.279 | bias = 0.000
#    - iteration: 3000 | loss (MSE) = 58370.256 | bias = 0.000
#    - iteration: 3100 | loss (MSE) = 58370.234 | bias = 0.000
#    - iteration: 3200 | loss (MSE) = 58370.211 | bias = 0.000
#    - iteration: 3300 | loss (MSE) = 58370.188 | bias = 0.000
#    - iteration: 3400 | loss (MSE) = 58370.166 | bias = 0.000
#    - iteration: 3500 | loss (MSE) = 58370.143 | bias = 0.000
#    - iteration: 3600 | loss (MSE) = 58370.121 | bias = 0.000
#    - iteration: 3700 | loss (MSE) = 58370.098 | bias = 0.000
#    - iteration: 3800 | loss (MSE) = 58370.075 | bias = 0.000
#    - iteration: 3900 | loss (MSE) = 58370.053 | bias = 0.000
#    - iteration: 4000 | loss (MSE) = 58370.030 | bias = 0.000
#    - iteration: 4100 | loss (MSE) = 58370.007 | bias = 0.000
#    - iteration: 4200 | loss (MSE) = 58369.985 | bias = 0.000
#    - iteration: 4300 | loss (MSE) = 58369.962 | bias = 0.000
#    - iteration: 4400 | loss (MSE) = 58369.940 | bias = 0.000
#    - iteration: 4500 | loss (MSE) = 58369.917 | bias = 0.000
#    - iteration: 4600 | loss (MSE) = 58369.894 | bias = 0.000
#    - iteration: 4700 | loss (MSE) = 58369.872 | bias = 0.000
#    - iteration: 4800 | loss (MSE) = 58369.849 | bias = 0.000
#    - iteration: 4900 | loss (MSE) = 58369.826 | bias = 0.000
#    - iteration: 5000 | loss (MSE) = 58369.804 | bias = 0.000
#    - iteration: 5100 | loss (MSE) = 58369.781 | bias = 0.000
#    - iteration: 5200 | loss (MSE) = 58369.759 | bias = 0.000
#    - iteration: 5300 | loss (MSE) = 58369.736 | bias = 0.000
#    - iteration: 5400 | loss (MSE) = 58369.713 | bias = 0.000
#    - iteration: 5500 | loss (MSE) = 58369.691 | bias = 0.000
#    - iteration: 5600 | loss (MSE) = 58369.668 | bias = 0.000
#    - iteration: 5700 | loss (MSE) = 58369.646 | bias = 0.000
#    - iteration: 5800 | loss (MSE) = 58369.623 | bias = 0.000
#    - iteration: 5900 | loss (MSE) = 58369.600 | bias = 0.000
#    - iteration: 6000 | loss (MSE) = 58369.578 | bias = 0.000
#    - iteration: 6100 | loss (MSE) = 58369.555 | bias = 0.000
#    - iteration: 6200 | loss (MSE) = 58369.532 | bias = 0.000
#    - iteration: 6300 | loss (MSE) = 58369.510 | bias = 0.000
#    - iteration: 6400 | loss (MSE) = 58369.487 | bias = 0.000
#    - iteration: 6500 | loss (MSE) = 58369.465 | bias = 0.000
#    - iteration: 6600 | loss (MSE) = 58369.442 | bias = 0.000
#    - iteration: 6700 | loss (MSE) = 58369.419 | bias = 0.000
#    - iteration: 6800 | loss (MSE) = 58369.397 | bias = 0.000
#    - iteration: 6900 | loss (MSE) = 58369.374 | bias = 0.000
#    - iteration: 7000 | loss (MSE) = 58369.351 | bias = 0.000
#    - iteration: 7100 | loss (MSE) = 58369.329 | bias = 0.000
#    - iteration: 7200 | loss (MSE) = 58369.306 | bias = 0.000
#    - iteration: 7300 | loss (MSE) = 58369.284 | bias = 0.000
#    - iteration: 7400 | loss (MSE) = 58369.261 | bias = 0.000
#    - iteration: 7500 | loss (MSE) = 58369.238 | bias = 0.000
#    - iteration: 7600 | loss (MSE) = 58369.216 | bias = 0.000
#    - iteration: 7700 | loss (MSE) = 58369.193 | bias = 0.000
#    - iteration: 7800 | loss (MSE) = 58369.170 | bias = 0.000
#    - iteration: 7900 | loss (MSE) = 58369.148 | bias = 0.000
#    - iteration: 8000 | loss (MSE) = 58369.125 | bias = 0.000
#    - iteration: 8100 | loss (MSE) = 58369.103 | bias = 0.000
#    - iteration: 8200 | loss (MSE) = 58369.080 | bias = 0.000
#    - iteration: 8300 | loss (MSE) = 58369.057 | bias = 0.000
#    - iteration: 8400 | loss (MSE) = 58369.035 | bias = 0.000
#    - iteration: 8500 | loss (MSE) = 58369.012 | bias = 0.000
#    - iteration: 8600 | loss (MSE) = 58368.989 | bias = 0.000
#    - iteration: 8700 | loss (MSE) = 58368.967 | bias = 0.000
#    - iteration: 8800 | loss (MSE) = 58368.944 | bias = 0.000
#    - iteration: 8900 | loss (MSE) = 58368.922 | bias = 0.000
#    - iteration: 9000 | loss (MSE) = 58368.899 | bias = 0.000
#    - iteration: 9100 | loss (MSE) = 58368.876 | bias = 0.000
#    - iteration: 9200 | loss (MSE) = 58368.854 | bias = 0.000
#    - iteration: 9300 | loss (MSE) = 58368.831 | bias = 0.000
#    - iteration: 9400 | loss (MSE) = 58368.808 | bias = 0.000
#    - iteration: 9500 | loss (MSE) = 58368.786 | bias = 0.000
#    - iteration: 9600 | loss (MSE) = 58368.763 | bias = 0.000
#    - iteration: 9700 | loss (MSE) = 58368.741 | bias = 0.000
#    - iteration: 9800 | loss (MSE) = 58368.718 | bias = 0.000
#    - iteration: 9900 | loss (MSE) = 58368.695 | bias = 0.000
# Treinamento Finalizado
# Iniciando treinamento( learning_rate = 1e-11 ):
#    - iteration: 0 | loss (MSE) = 58370.933 | bias = 0.000
#    - iteration: 100 | loss (MSE) = 58370.707 | bias = 0.000
#    - iteration: 200 | loss (MSE) = 58370.481 | bias = 0.000
#    - iteration: 300 | loss (MSE) = 58370.254 | bias = 0.000
#    - iteration: 400 | loss (MSE) = 58370.028 | bias = 0.000
#    - iteration: 500 | loss (MSE) = 58369.802 | bias = 0.000
#    - iteration: 600 | loss (MSE) = 58369.576 | bias = 0.000
#    - iteration: 700 | loss (MSE) = 58369.349 | bias = 0.000
#    - iteration: 800 | loss (MSE) = 58369.123 | bias = 0.000
#    - iteration: 900 | loss (MSE) = 58368.897 | bias = 0.000
#    - iteration: 1000 | loss (MSE) = 58368.671 | bias = 0.000
#    - iteration: 1100 | loss (MSE) = 58368.444 | bias = 0.000
#    - iteration: 1200 | loss (MSE) = 58368.218 | bias = 0.000
#    - iteration: 1300 | loss (MSE) = 58367.992 | bias = 0.000
#    - iteration: 1400 | loss (MSE) = 58367.766 | bias = 0.000
#    - iteration: 1500 | loss (MSE) = 58367.540 | bias = 0.000
#    - iteration: 1600 | loss (MSE) = 58367.313 | bias = 0.000
#    - iteration: 1700 | loss (MSE) = 58367.087 | bias = 0.000
#    - iteration: 1800 | loss (MSE) = 58366.861 | bias = 0.000
#    - iteration: 1900 | loss (MSE) = 58366.635 | bias = 0.000
#    - iteration: 2000 | loss (MSE) = 58366.408 | bias = 0.000
#    - iteration: 2100 | loss (MSE) = 58366.182 | bias = 0.000
#    - iteration: 2200 | loss (MSE) = 58365.956 | bias = 0.000
#    - iteration: 2300 | loss (MSE) = 58365.730 | bias = 0.000
#    - iteration: 2400 | loss (MSE) = 58365.504 | bias = 0.000
#    - iteration: 2500 | loss (MSE) = 58365.277 | bias = 0.000
#    - iteration: 2600 | loss (MSE) = 58365.051 | bias = 0.000
#    - iteration: 2700 | loss (MSE) = 58364.825 | bias = 0.000
#    - iteration: 2800 | loss (MSE) = 58364.599 | bias = 0.000
#    - iteration: 2900 | loss (MSE) = 58364.373 | bias = 0.000
#    - iteration: 3000 | loss (MSE) = 58364.146 | bias = 0.000
#    - iteration: 3100 | loss (MSE) = 58363.920 | bias = 0.000
#    - iteration: 3200 | loss (MSE) = 58363.694 | bias = 0.000
#    - iteration: 3300 | loss (MSE) = 58363.468 | bias = 0.000
#    - iteration: 3400 | loss (MSE) = 58363.242 | bias = 0.000
#    - iteration: 3500 | loss (MSE) = 58363.015 | bias = 0.000
#    - iteration: 3600 | loss (MSE) = 58362.789 | bias = 0.000
#    - iteration: 3700 | loss (MSE) = 58362.563 | bias = 0.000
#    - iteration: 3800 | loss (MSE) = 58362.337 | bias = 0.000
#    - iteration: 3900 | loss (MSE) = 58362.111 | bias = 0.000
#    - iteration: 4000 | loss (MSE) = 58361.885 | bias = 0.000
#    - iteration: 4100 | loss (MSE) = 58361.658 | bias = 0.000
#    - iteration: 4200 | loss (MSE) = 58361.432 | bias = 0.000
#    - iteration: 4300 | loss (MSE) = 58361.206 | bias = 0.000
#    - iteration: 4400 | loss (MSE) = 58360.980 | bias = 0.000
#    - iteration: 4500 | loss (MSE) = 58360.754 | bias = 0.000
#    - iteration: 4600 | loss (MSE) = 58360.528 | bias = 0.000
#    - iteration: 4700 | loss (MSE) = 58360.301 | bias = 0.000
#    - iteration: 4800 | loss (MSE) = 58360.075 | bias = 0.000
#    - iteration: 4900 | loss (MSE) = 58359.849 | bias = 0.000
#    - iteration: 5000 | loss (MSE) = 58359.623 | bias = 0.000
#    - iteration: 5100 | loss (MSE) = 58359.397 | bias = 0.000
#    - iteration: 5200 | loss (MSE) = 58359.171 | bias = 0.000
#    - iteration: 5300 | loss (MSE) = 58358.945 | bias = 0.000
#    - iteration: 5400 | loss (MSE) = 58358.718 | bias = 0.000
#    - iteration: 5500 | loss (MSE) = 58358.492 | bias = 0.000
#    - iteration: 5600 | loss (MSE) = 58358.266 | bias = 0.000
#    - iteration: 5700 | loss (MSE) = 58358.040 | bias = 0.000
#    - iteration: 5800 | loss (MSE) = 58357.814 | bias = 0.000
#    - iteration: 5900 | loss (MSE) = 58357.588 | bias = 0.000
#    - iteration: 6000 | loss (MSE) = 58357.362 | bias = 0.000
#    - iteration: 6100 | loss (MSE) = 58357.135 | bias = 0.000
#    - iteration: 6200 | loss (MSE) = 58356.909 | bias = 0.000
#    - iteration: 6300 | loss (MSE) = 58356.683 | bias = 0.000
#    - iteration: 6400 | loss (MSE) = 58356.457 | bias = 0.000
#    - iteration: 6500 | loss (MSE) = 58356.231 | bias = 0.000
#    - iteration: 6600 | loss (MSE) = 58356.005 | bias = 0.000
#    - iteration: 6700 | loss (MSE) = 58355.779 | bias = 0.000
#    - iteration: 6800 | loss (MSE) = 58355.553 | bias = 0.000
#    - iteration: 6900 | loss (MSE) = 58355.327 | bias = 0.000
#    - iteration: 7000 | loss (MSE) = 58355.100 | bias = 0.000
#    - iteration: 7100 | loss (MSE) = 58354.874 | bias = 0.000
#    - iteration: 7200 | loss (MSE) = 58354.648 | bias = 0.000
#    - iteration: 7300 | loss (MSE) = 58354.422 | bias = 0.000
#    - iteration: 7400 | loss (MSE) = 58354.196 | bias = 0.000
#    - iteration: 7500 | loss (MSE) = 58353.970 | bias = 0.000
#    - iteration: 7600 | loss (MSE) = 58353.744 | bias = 0.000
#    - iteration: 7700 | loss (MSE) = 58353.518 | bias = 0.000
#    - iteration: 7800 | loss (MSE) = 58353.292 | bias = 0.000
#    - iteration: 7900 | loss (MSE) = 58353.066 | bias = 0.000
#    - iteration: 8000 | loss (MSE) = 58352.839 | bias = 0.000
#    - iteration: 8100 | loss (MSE) = 58352.613 | bias = 0.000
#    - iteration: 8200 | loss (MSE) = 58352.387 | bias = 0.000
#    - iteration: 8300 | loss (MSE) = 58352.161 | bias = 0.000
#    - iteration: 8400 | loss (MSE) = 58351.935 | bias = 0.000
#    - iteration: 8500 | loss (MSE) = 58351.709 | bias = 0.000
#    - iteration: 8600 | loss (MSE) = 58351.483 | bias = 0.000
#    - iteration: 8700 | loss (MSE) = 58351.257 | bias = 0.000
#    - iteration: 8800 | loss (MSE) = 58351.031 | bias = 0.000
#    - iteration: 8900 | loss (MSE) = 58350.805 | bias = 0.000
#    - iteration: 9000 | loss (MSE) = 58350.579 | bias = 0.000
#    - iteration: 9100 | loss (MSE) = 58350.353 | bias = 0.000
#    - iteration: 9200 | loss (MSE) = 58350.127 | bias = 0.000
#    - iteration: 9300 | loss (MSE) = 58349.900 | bias = 0.000
#    - iteration: 9400 | loss (MSE) = 58349.674 | bias = 0.000
#    - iteration: 9500 | loss (MSE) = 58349.448 | bias = 0.000
#    - iteration: 9600 | loss (MSE) = 58349.222 | bias = 0.000
#    - iteration: 9700 | loss (MSE) = 58348.996 | bias = 0.000
#    - iteration: 9800 | loss (MSE) = 58348.770 | bias = 0.000
#    - iteration: 9900 | loss (MSE) = 58348.544 | bias = 0.000
# Treinamento Finalizado
# Iniciando treinamento( learning_rate = 1e-10 ):
#    - iteration: 0 | loss (MSE) = 58370.913 | bias = 0.000
#    - iteration: 100 | loss (MSE) = 58368.650 | bias = 0.000
#    - iteration: 200 | loss (MSE) = 58366.388 | bias = 0.000
#    - iteration: 300 | loss (MSE) = 58364.126 | bias = 0.000
#    - iteration: 400 | loss (MSE) = 58361.864 | bias = 0.000
#    - iteration: 500 | loss (MSE) = 58359.603 | bias = 0.000
#    - iteration: 600 | loss (MSE) = 58357.341 | bias = 0.000
#    - iteration: 700 | loss (MSE) = 58355.080 | bias = 0.000
#    - iteration: 800 | loss (MSE) = 58352.819 | bias = 0.000
#    - iteration: 900 | loss (MSE) = 58350.558 | bias = 0.000
#    - iteration: 1000 | loss (MSE) = 58348.298 | bias = 0.000
#    - iteration: 1100 | loss (MSE) = 58346.037 | bias = 0.000
#    - iteration: 1200 | loss (MSE) = 58343.777 | bias = 0.000
#    - iteration: 1300 | loss (MSE) = 58341.517 | bias = 0.000
#    - iteration: 1400 | loss (MSE) = 58339.258 | bias = 0.000
#    - iteration: 1500 | loss (MSE) = 58336.998 | bias = 0.000
#    - iteration: 1600 | loss (MSE) = 58334.739 | bias = 0.000
#    - iteration: 1700 | loss (MSE) = 58332.480 | bias = 0.000
#    - iteration: 1800 | loss (MSE) = 58330.221 | bias = 0.000
#    - iteration: 1900 | loss (MSE) = 58327.962 | bias = 0.000
#    - iteration: 2000 | loss (MSE) = 58325.703 | bias = 0.000
#    - iteration: 2100 | loss (MSE) = 58323.445 | bias = 0.000
#    - iteration: 2200 | loss (MSE) = 58321.187 | bias = 0.000
#    - iteration: 2300 | loss (MSE) = 58318.929 | bias = 0.000
#    - iteration: 2400 | loss (MSE) = 58316.672 | bias = 0.000
#    - iteration: 2500 | loss (MSE) = 58314.414 | bias = 0.000
#    - iteration: 2600 | loss (MSE) = 58312.157 | bias = 0.000
#    - iteration: 2700 | loss (MSE) = 58309.900 | bias = 0.000
#    - iteration: 2800 | loss (MSE) = 58307.643 | bias = 0.000
#    - iteration: 2900 | loss (MSE) = 58305.386 | bias = 0.000
#    - iteration: 3000 | loss (MSE) = 58303.130 | bias = 0.000
#    - iteration: 3100 | loss (MSE) = 58300.874 | bias = 0.000
#    - iteration: 3200 | loss (MSE) = 58298.618 | bias = 0.000
#    - iteration: 3300 | loss (MSE) = 58296.362 | bias = 0.000
#    - iteration: 3400 | loss (MSE) = 58294.106 | bias = 0.000
#    - iteration: 3500 | loss (MSE) = 58291.851 | bias = 0.000
#    - iteration: 3600 | loss (MSE) = 58289.596 | bias = 0.000
#    - iteration: 3700 | loss (MSE) = 58287.341 | bias = 0.000
#    - iteration: 3800 | loss (MSE) = 58285.086 | bias = 0.000
#    - iteration: 3900 | loss (MSE) = 58282.831 | bias = 0.000
#    - iteration: 4000 | loss (MSE) = 58280.577 | bias = 0.000
#    - iteration: 4100 | loss (MSE) = 58278.323 | bias = 0.000
#    - iteration: 4200 | loss (MSE) = 58276.069 | bias = 0.000
#    - iteration: 4300 | loss (MSE) = 58273.815 | bias = 0.000
#    - iteration: 4400 | loss (MSE) = 58271.561 | bias = 0.000
#    - iteration: 4500 | loss (MSE) = 58269.308 | bias = 0.000
#    - iteration: 4600 | loss (MSE) = 58267.055 | bias = 0.000
#    - iteration: 4700 | loss (MSE) = 58264.802 | bias = 0.000
#    - iteration: 4800 | loss (MSE) = 58262.549 | bias = 0.000
#    - iteration: 4900 | loss (MSE) = 58260.297 | bias = 0.000
#    - iteration: 5000 | loss (MSE) = 58258.044 | bias = 0.000
#    - iteration: 5100 | loss (MSE) = 58255.792 | bias = 0.000
#    - iteration: 5200 | loss (MSE) = 58253.540 | bias = 0.000
#    - iteration: 5300 | loss (MSE) = 58251.289 | bias = 0.000
#    - iteration: 5400 | loss (MSE) = 58249.037 | bias = 0.000
#    - iteration: 5500 | loss (MSE) = 58246.786 | bias = 0.000
#    - iteration: 5600 | loss (MSE) = 58244.535 | bias = 0.000
#    - iteration: 5700 | loss (MSE) = 58242.284 | bias = 0.000
#    - iteration: 5800 | loss (MSE) = 58240.033 | bias = 0.000
#    - iteration: 5900 | loss (MSE) = 58237.783 | bias = 0.000
#    - iteration: 6000 | loss (MSE) = 58235.533 | bias = 0.000
#    - iteration: 6100 | loss (MSE) = 58233.283 | bias = 0.000
#    - iteration: 6200 | loss (MSE) = 58231.033 | bias = 0.000
#    - iteration: 6300 | loss (MSE) = 58228.783 | bias = 0.000
#    - iteration: 6400 | loss (MSE) = 58226.534 | bias = 0.000
#    - iteration: 6500 | loss (MSE) = 58224.285 | bias = 0.000
#    - iteration: 6600 | loss (MSE) = 58222.036 | bias = 0.000
#    - iteration: 6700 | loss (MSE) = 58219.787 | bias = 0.000
#    - iteration: 6800 | loss (MSE) = 58217.538 | bias = 0.000
#    - iteration: 6900 | loss (MSE) = 58215.290 | bias = 0.000
#    - iteration: 7000 | loss (MSE) = 58213.042 | bias = 0.000
#    - iteration: 7100 | loss (MSE) = 58210.794 | bias = 0.000
#    - iteration: 7200 | loss (MSE) = 58208.546 | bias = 0.000
#    - iteration: 7300 | loss (MSE) = 58206.298 | bias = 0.000
#    - iteration: 7400 | loss (MSE) = 58204.051 | bias = 0.000
#    - iteration: 7500 | loss (MSE) = 58201.804 | bias = 0.000
#    - iteration: 7600 | loss (MSE) = 58199.557 | bias = 0.000
#    - iteration: 7700 | loss (MSE) = 58197.310 | bias = 0.000
#    - iteration: 7800 | loss (MSE) = 58195.063 | bias = 0.000
#    - iteration: 7900 | loss (MSE) = 58192.817 | bias = 0.000
#    - iteration: 8000 | loss (MSE) = 58190.571 | bias = 0.000
#    - iteration: 8100 | loss (MSE) = 58188.325 | bias = 0.000
#    - iteration: 8200 | loss (MSE) = 58186.079 | bias = 0.000
#    - iteration: 8300 | loss (MSE) = 58183.834 | bias = 0.000
#    - iteration: 8400 | loss (MSE) = 58181.588 | bias = 0.000
#    - iteration: 8500 | loss (MSE) = 58179.343 | bias = 0.000
#    - iteration: 8600 | loss (MSE) = 58177.098 | bias = 0.000
#    - iteration: 8700 | loss (MSE) = 58174.854 | bias = 0.000
#    - iteration: 8800 | loss (MSE) = 58172.609 | bias = 0.000
#    - iteration: 8900 | loss (MSE) = 58170.365 | bias = 0.000
#    - iteration: 9000 | loss (MSE) = 58168.121 | bias = 0.000
#    - iteration: 9100 | loss (MSE) = 58165.877 | bias = 0.000
#    - iteration: 9200 | loss (MSE) = 58163.633 | bias = 0.000
#    - iteration: 9300 | loss (MSE) = 58161.390 | bias = 0.000
#    - iteration: 9400 | loss (MSE) = 58159.147 | bias = 0.000
#    - iteration: 9500 | loss (MSE) = 58156.903 | bias = 0.000
#    - iteration: 9600 | loss (MSE) = 58154.661 | bias = 0.000
#    - iteration: 9700 | loss (MSE) = 58152.418 | bias = 0.000
#    - iteration: 9800 | loss (MSE) = 58150.175 | bias = 0.000
#    - iteration: 9900 | loss (MSE) = 58147.933 | bias = 0.000
# Treinamento Finalizado
# Iniciando treinamento( learning_rate = 1e-09 ):
#    - iteration: 0 | loss (MSE) = 58370.709 | bias = 0.000
#    - iteration: 100 | loss (MSE) = 58348.094 | bias = 0.000
#    - iteration: 200 | loss (MSE) = 58325.500 | bias = 0.000
#    - iteration: 300 | loss (MSE) = 58302.927 | bias = 0.000
#    - iteration: 400 | loss (MSE) = 58280.374 | bias = 0.000
#    - iteration: 500 | loss (MSE) = 58257.842 | bias = 0.000
#    - iteration: 600 | loss (MSE) = 58235.330 | bias = 0.000
#    - iteration: 700 | loss (MSE) = 58212.839 | bias = 0.000
#    - iteration: 800 | loss (MSE) = 58190.368 | bias = 0.000
#    - iteration: 900 | loss (MSE) = 58167.918 | bias = 0.000
#    - iteration: 1000 | loss (MSE) = 58145.489 | bias = 0.000
#    - iteration: 1100 | loss (MSE) = 58123.080 | bias = 0.000
#    - iteration: 1200 | loss (MSE) = 58100.692 | bias = 0.000
#    - iteration: 1300 | loss (MSE) = 58078.324 | bias = 0.000
#    - iteration: 1400 | loss (MSE) = 58055.976 | bias = 0.000
#    - iteration: 1500 | loss (MSE) = 58033.649 | bias = 0.000
#    - iteration: 1600 | loss (MSE) = 58011.342 | bias = 0.000
#    - iteration: 1700 | loss (MSE) = 57989.056 | bias = 0.000
#    - iteration: 1800 | loss (MSE) = 57966.790 | bias = 0.000
#    - iteration: 1900 | loss (MSE) = 57944.545 | bias = 0.000
#    - iteration: 2000 | loss (MSE) = 57922.319 | bias = 0.000
#    - iteration: 2100 | loss (MSE) = 57900.115 | bias = 0.000
#    - iteration: 2200 | loss (MSE) = 57877.930 | bias = 0.000
#    - iteration: 2300 | loss (MSE) = 57855.766 | bias = 0.000
#    - iteration: 2400 | loss (MSE) = 57833.622 | bias = 0.000
#    - iteration: 2500 | loss (MSE) = 57811.498 | bias = 0.000
#    - iteration: 2600 | loss (MSE) = 57789.394 | bias = 0.000
#    - iteration: 2700 | loss (MSE) = 57767.311 | bias = 0.000
#    - iteration: 2800 | loss (MSE) = 57745.247 | bias = 0.000
#    - iteration: 2900 | loss (MSE) = 57723.204 | bias = 0.001
#    - iteration: 3000 | loss (MSE) = 57701.182 | bias = 0.001
#    - iteration: 3100 | loss (MSE) = 57679.179 | bias = 0.001
#    - iteration: 3200 | loss (MSE) = 57657.196 | bias = 0.001
#    - iteration: 3300 | loss (MSE) = 57635.234 | bias = 0.001
#    - iteration: 3400 | loss (MSE) = 57613.291 | bias = 0.001
#    - iteration: 3500 | loss (MSE) = 57591.369 | bias = 0.001
#    - iteration: 3600 | loss (MSE) = 57569.466 | bias = 0.001
#    - iteration: 3700 | loss (MSE) = 57547.584 | bias = 0.001
#    - iteration: 3800 | loss (MSE) = 57525.721 | bias = 0.001
#    - iteration: 3900 | loss (MSE) = 57503.879 | bias = 0.001
#    - iteration: 4000 | loss (MSE) = 57482.057 | bias = 0.001
#    - iteration: 4100 | loss (MSE) = 57460.254 | bias = 0.001
#    - iteration: 4200 | loss (MSE) = 57438.471 | bias = 0.001
#    - iteration: 4300 | loss (MSE) = 57416.709 | bias = 0.001
#    - iteration: 4400 | loss (MSE) = 57394.966 | bias = 0.001
#    - iteration: 4500 | loss (MSE) = 57373.243 | bias = 0.001
#    - iteration: 4600 | loss (MSE) = 57351.540 | bias = 0.001
#    - iteration: 4700 | loss (MSE) = 57329.857 | bias = 0.001
#    - iteration: 4800 | loss (MSE) = 57308.193 | bias = 0.001
#    - iteration: 4900 | loss (MSE) = 57286.550 | bias = 0.001
#    - iteration: 5000 | loss (MSE) = 57264.926 | bias = 0.001
#    - iteration: 5100 | loss (MSE) = 57243.322 | bias = 0.001
#    - iteration: 5200 | loss (MSE) = 57221.737 | bias = 0.001
#    - iteration: 5300 | loss (MSE) = 57200.173 | bias = 0.001
#    - iteration: 5400 | loss (MSE) = 57178.628 | bias = 0.001
#    - iteration: 5500 | loss (MSE) = 57157.103 | bias = 0.001
#    - iteration: 5600 | loss (MSE) = 57135.597 | bias = 0.001
#    - iteration: 5700 | loss (MSE) = 57114.111 | bias = 0.001
#    - iteration: 5800 | loss (MSE) = 57092.645 | bias = 0.001
#    - iteration: 5900 | loss (MSE) = 57071.198 | bias = 0.001
#    - iteration: 6000 | loss (MSE) = 57049.771 | bias = 0.001
#    - iteration: 6100 | loss (MSE) = 57028.364 | bias = 0.001
#    - iteration: 6200 | loss (MSE) = 57006.976 | bias = 0.001
#    - iteration: 6300 | loss (MSE) = 56985.607 | bias = 0.001
#    - iteration: 6400 | loss (MSE) = 56964.258 | bias = 0.001
#    - iteration: 6500 | loss (MSE) = 56942.929 | bias = 0.001
#    - iteration: 6600 | loss (MSE) = 56921.619 | bias = 0.001
#    - iteration: 6700 | loss (MSE) = 56900.329 | bias = 0.001
#    - iteration: 6800 | loss (MSE) = 56879.058 | bias = 0.001
#    - iteration: 6900 | loss (MSE) = 56857.806 | bias = 0.001
#    - iteration: 7000 | loss (MSE) = 56836.574 | bias = 0.001
#    - iteration: 7100 | loss (MSE) = 56815.361 | bias = 0.001
#    - iteration: 7200 | loss (MSE) = 56794.168 | bias = 0.001
#    - iteration: 7300 | loss (MSE) = 56772.994 | bias = 0.001
#    - iteration: 7400 | loss (MSE) = 56751.839 | bias = 0.001
#    - iteration: 7500 | loss (MSE) = 56730.704 | bias = 0.001
#    - iteration: 7600 | loss (MSE) = 56709.588 | bias = 0.001
#    - iteration: 7700 | loss (MSE) = 56688.491 | bias = 0.001
#    - iteration: 7800 | loss (MSE) = 56667.414 | bias = 0.001
#    - iteration: 7900 | loss (MSE) = 56646.356 | bias = 0.001
#    - iteration: 8000 | loss (MSE) = 56625.317 | bias = 0.001
#    - iteration: 8100 | loss (MSE) = 56604.297 | bias = 0.001
#    - iteration: 8200 | loss (MSE) = 56583.297 | bias = 0.001
#    - iteration: 8300 | loss (MSE) = 56562.315 | bias = 0.001
#    - iteration: 8400 | loss (MSE) = 56541.353 | bias = 0.001
#    - iteration: 8500 | loss (MSE) = 56520.410 | bias = 0.001
#    - iteration: 8600 | loss (MSE) = 56499.486 | bias = 0.001
#    - iteration: 8700 | loss (MSE) = 56478.581 | bias = 0.001
#    - iteration: 8800 | loss (MSE) = 56457.696 | bias = 0.002
#    - iteration: 8900 | loss (MSE) = 56436.829 | bias = 0.002
#    - iteration: 9000 | loss (MSE) = 56415.981 | bias = 0.002
#    - iteration: 9100 | loss (MSE) = 56395.153 | bias = 0.002
#    - iteration: 9200 | loss (MSE) = 56374.343 | bias = 0.002
#    - iteration: 9300 | loss (MSE) = 56353.553 | bias = 0.002
#    - iteration: 9400 | loss (MSE) = 56332.781 | bias = 0.002
#    - iteration: 9500 | loss (MSE) = 56312.029 | bias = 0.002
#    - iteration: 9600 | loss (MSE) = 56291.295 | bias = 0.002
#    - iteration: 9700 | loss (MSE) = 56270.580 | bias = 0.002
#    - iteration: 9800 | loss (MSE) = 56249.885 | bias = 0.002
#    - iteration: 9900 | loss (MSE) = 56229.208 | bias = 0.002
# Treinamento Finalizado
# Iniciando treinamento( learning_rate = 1e-08 ):
#    - iteration: 0 | loss (MSE) = 58368.673 | bias = 0.000
#    - iteration: 100 | loss (MSE) = 58143.467 | bias = 0.000
#    - iteration: 200 | loss (MSE) = 57920.311 | bias = 0.000
#    - iteration: 300 | loss (MSE) = 57699.187 | bias = 0.001
#    - iteration: 400 | loss (MSE) = 57480.075 | bias = 0.001
#    - iteration: 500 | loss (MSE) = 57262.958 | bias = 0.001
#    - iteration: 600 | loss (MSE) = 57047.817 | bias = 0.001
#    - iteration: 700 | loss (MSE) = 56834.634 | bias = 0.001
#    - iteration: 800 | loss (MSE) = 56623.390 | bias = 0.001
#    - iteration: 900 | loss (MSE) = 56414.067 | bias = 0.002
#    - iteration: 1000 | loss (MSE) = 56206.649 | bias = 0.002
#    - iteration: 1100 | loss (MSE) = 56001.117 | bias = 0.002
#    - iteration: 1200 | loss (MSE) = 55797.454 | bias = 0.002
#    - iteration: 1300 | loss (MSE) = 55595.643 | bias = 0.002
#    - iteration: 1400 | loss (MSE) = 55395.667 | bias = 0.002
#    - iteration: 1500 | loss (MSE) = 55197.508 | bias = 0.003
#    - iteration: 1600 | loss (MSE) = 55001.151 | bias = 0.003
#    - iteration: 1700 | loss (MSE) = 54806.578 | bias = 0.003
#    - iteration: 1800 | loss (MSE) = 54613.773 | bias = 0.003
#    - iteration: 1900 | loss (MSE) = 54422.719 | bias = 0.003
#    - iteration: 2000 | loss (MSE) = 54233.401 | bias = 0.003
#    - iteration: 2100 | loss (MSE) = 54045.803 | bias = 0.004
#    - iteration: 2200 | loss (MSE) = 53859.908 | bias = 0.004
#    - iteration: 2300 | loss (MSE) = 53675.701 | bias = 0.004
#    - iteration: 2400 | loss (MSE) = 53493.167 | bias = 0.004
#    - iteration: 2500 | loss (MSE) = 53312.289 | bias = 0.004
#    - iteration: 2600 | loss (MSE) = 53133.054 | bias = 0.004
#    - iteration: 2700 | loss (MSE) = 52955.444 | bias = 0.004
#    - iteration: 2800 | loss (MSE) = 52779.447 | bias = 0.005
#    - iteration: 2900 | loss (MSE) = 52605.045 | bias = 0.005
#    - iteration: 3000 | loss (MSE) = 52432.226 | bias = 0.005
#    - iteration: 3100 | loss (MSE) = 52260.975 | bias = 0.005
#    - iteration: 3200 | loss (MSE) = 52091.276 | bias = 0.005
#    - iteration: 3300 | loss (MSE) = 51923.116 | bias = 0.005
#    - iteration: 3400 | loss (MSE) = 51756.480 | bias = 0.006
#    - iteration: 3500 | loss (MSE) = 51591.355 | bias = 0.006
#    - iteration: 3600 | loss (MSE) = 51427.726 | bias = 0.006
#    - iteration: 3700 | loss (MSE) = 51265.579 | bias = 0.006
#    - iteration: 3800 | loss (MSE) = 51104.902 | bias = 0.006
#    - iteration: 3900 | loss (MSE) = 50945.680 | bias = 0.006
#    - iteration: 4000 | loss (MSE) = 50787.900 | bias = 0.006
#    - iteration: 4100 | loss (MSE) = 50631.548 | bias = 0.007
#    - iteration: 4200 | loss (MSE) = 50476.613 | bias = 0.007
#    - iteration: 4300 | loss (MSE) = 50323.079 | bias = 0.007
#    - iteration: 4400 | loss (MSE) = 50170.936 | bias = 0.007
#    - iteration: 4500 | loss (MSE) = 50020.169 | bias = 0.007
#    - iteration: 4600 | loss (MSE) = 49870.766 | bias = 0.007
#    - iteration: 4700 | loss (MSE) = 49722.714 | bias = 0.007
#    - iteration: 4800 | loss (MSE) = 49576.002 | bias = 0.008
#    - iteration: 4900 | loss (MSE) = 49430.616 | bias = 0.008
#    - iteration: 5000 | loss (MSE) = 49286.544 | bias = 0.008
#    - iteration: 5100 | loss (MSE) = 49143.775 | bias = 0.008
#    - iteration: 5200 | loss (MSE) = 49002.296 | bias = 0.008
#    - iteration: 5300 | loss (MSE) = 48862.096 | bias = 0.008
#    - iteration: 5400 | loss (MSE) = 48723.162 | bias = 0.008
#    - iteration: 5500 | loss (MSE) = 48585.483 | bias = 0.009
#    - iteration: 5600 | loss (MSE) = 48449.047 | bias = 0.009
#    - iteration: 5700 | loss (MSE) = 48313.844 | bias = 0.009
#    - iteration: 5800 | loss (MSE) = 48179.861 | bias = 0.009
#    - iteration: 5900 | loss (MSE) = 48047.087 | bias = 0.009
#    - iteration: 6000 | loss (MSE) = 47915.511 | bias = 0.009
#    - iteration: 6100 | loss (MSE) = 47785.123 | bias = 0.009
#    - iteration: 6200 | loss (MSE) = 47655.910 | bias = 0.010
#    - iteration: 6300 | loss (MSE) = 47527.863 | bias = 0.010
#    - iteration: 6400 | loss (MSE) = 47400.970 | bias = 0.010
#    - iteration: 6500 | loss (MSE) = 47275.222 | bias = 0.010
#    - iteration: 6600 | loss (MSE) = 47150.606 | bias = 0.010
#    - iteration: 6700 | loss (MSE) = 47027.114 | bias = 0.010
#    - iteration: 6800 | loss (MSE) = 46904.734 | bias = 0.010
#    - iteration: 6900 | loss (MSE) = 46783.457 | bias = 0.011
#    - iteration: 7000 | loss (MSE) = 46663.271 | bias = 0.011
#    - iteration: 7100 | loss (MSE) = 46544.168 | bias = 0.011
#    - iteration: 7200 | loss (MSE) = 46426.137 | bias = 0.011
#    - iteration: 7300 | loss (MSE) = 46309.168 | bias = 0.011
#    - iteration: 7400 | loss (MSE) = 46193.252 | bias = 0.011
#    - iteration: 7500 | loss (MSE) = 46078.378 | bias = 0.011
#    - iteration: 7600 | loss (MSE) = 45964.537 | bias = 0.011
#    - iteration: 7700 | loss (MSE) = 45851.720 | bias = 0.012
#    - iteration: 7800 | loss (MSE) = 45739.917 | bias = 0.012
#    - iteration: 7900 | loss (MSE) = 45629.119 | bias = 0.012
#    - iteration: 8000 | loss (MSE) = 45519.316 | bias = 0.012
#    - iteration: 8100 | loss (MSE) = 45410.500 | bias = 0.012
#    - iteration: 8200 | loss (MSE) = 45302.661 | bias = 0.012
#    - iteration: 8300 | loss (MSE) = 45195.790 | bias = 0.012
#    - iteration: 8400 | loss (MSE) = 45089.879 | bias = 0.013
#    - iteration: 8500 | loss (MSE) = 44984.918 | bias = 0.013
#    - iteration: 8600 | loss (MSE) = 44880.899 | bias = 0.013
#    - iteration: 8700 | loss (MSE) = 44777.813 | bias = 0.013
#    - iteration: 8800 | loss (MSE) = 44675.651 | bias = 0.013
#    - iteration: 8900 | loss (MSE) = 44574.406 | bias = 0.013
#    - iteration: 9000 | loss (MSE) = 44474.067 | bias = 0.013
#    - iteration: 9100 | loss (MSE) = 44374.628 | bias = 0.013
#    - iteration: 9200 | loss (MSE) = 44276.080 | bias = 0.014
#    - iteration: 9300 | loss (MSE) = 44178.414 | bias = 0.014
#    - iteration: 9400 | loss (MSE) = 44081.623 | bias = 0.014
#    - iteration: 9500 | loss (MSE) = 43985.698 | bias = 0.014
#    - iteration: 9600 | loss (MSE) = 43890.632 | bias = 0.014
#    - iteration: 9700 | loss (MSE) = 43796.416 | bias = 0.014
#    - iteration: 9800 | loss (MSE) = 43703.043 | bias = 0.014
#    - iteration: 9900 | loss (MSE) = 43610.505 | bias = 0.014
# Treinamento Finalizado
# Iniciando treinamento( learning_rate = 1e-07 ):
#    - iteration: 0 | loss (MSE) = 58348.315 | bias = 0.000
#    - iteration: 100 | loss (MSE) = 56187.646 | bias = 0.002
#    - iteration: 200 | loss (MSE) = 54215.670 | bias = 0.003
#    - iteration: 300 | loss (MSE) = 52415.689 | bias = 0.005
#    - iteration: 400 | loss (MSE) = 50772.482 | bias = 0.006
#    - iteration: 500 | loss (MSE) = 49272.175 | bias = 0.008
#    - iteration: 600 | loss (MSE) = 47902.124 | bias = 0.009
#    - iteration: 700 | loss (MSE) = 46650.802 | bias = 0.011
#    - iteration: 800 | loss (MSE) = 45507.706 | bias = 0.012
#    - iteration: 900 | loss (MSE) = 44463.259 | bias = 0.013
#    - iteration: 1000 | loss (MSE) = 43508.735 | bias = 0.014
#    - iteration: 1100 | loss (MSE) = 42636.179 | bias = 0.016
#    - iteration: 1200 | loss (MSE) = 41838.339 | bias = 0.017
#    - iteration: 1300 | loss (MSE) = 41108.609 | bias = 0.018
#    - iteration: 1400 | loss (MSE) = 40440.963 | bias = 0.019
#    - iteration: 1500 | loss (MSE) = 39829.912 | bias = 0.020
#    - iteration: 1600 | loss (MSE) = 39270.451 | bias = 0.021
#    - iteration: 1700 | loss (MSE) = 38758.019 | bias = 0.022
#    - iteration: 1800 | loss (MSE) = 38288.460 | bias = 0.023
#    - iteration: 1900 | loss (MSE) = 37857.983 | bias = 0.024
#    - iteration: 2000 | loss (MSE) = 37463.134 | bias = 0.025
#    - iteration: 2100 | loss (MSE) = 37100.767 | bias = 0.025
#    - iteration: 2200 | loss (MSE) = 36768.010 | bias = 0.026
#    - iteration: 2300 | loss (MSE) = 36462.249 | bias = 0.027
#    - iteration: 2400 | loss (MSE) = 36181.100 | bias = 0.028
#    - iteration: 2500 | loss (MSE) = 35922.390 | bias = 0.028
#    - iteration: 2600 | loss (MSE) = 35684.139 | bias = 0.029
#    - iteration: 2700 | loss (MSE) = 35464.541 | bias = 0.030
#    - iteration: 2800 | loss (MSE) = 35261.952 | bias = 0.030
#    - iteration: 2900 | loss (MSE) = 35074.871 | bias = 0.031
#    - iteration: 3000 | loss (MSE) = 34901.931 | bias = 0.032
#    - iteration: 3100 | loss (MSE) = 34741.887 | bias = 0.032
#    - iteration: 3200 | loss (MSE) = 34593.603 | bias = 0.033
#    - iteration: 3300 | loss (MSE) = 34456.043 | bias = 0.033
#    - iteration: 3400 | loss (MSE) = 34328.265 | bias = 0.034
#    - iteration: 3500 | loss (MSE) = 34209.409 | bias = 0.035
#    - iteration: 3600 | loss (MSE) = 34098.690 | bias = 0.035
#    - iteration: 3700 | loss (MSE) = 33995.394 | bias = 0.036
#    - iteration: 3800 | loss (MSE) = 33898.869 | bias = 0.036
#    - iteration: 3900 | loss (MSE) = 33808.523 | bias = 0.037
#    - iteration: 4000 | loss (MSE) = 33723.815 | bias = 0.037
#    - iteration: 4100 | loss (MSE) = 33644.250 | bias = 0.038
#    - iteration: 4200 | loss (MSE) = 33569.379 | bias = 0.038
#    - iteration: 4300 | loss (MSE) = 33498.794 | bias = 0.039
#    - iteration: 4400 | loss (MSE) = 33432.120 | bias = 0.039
#    - iteration: 4500 | loss (MSE) = 33369.016 | bias = 0.039
#    - iteration: 4600 | loss (MSE) = 33309.173 | bias = 0.040
#    - iteration: 4700 | loss (MSE) = 33252.308 | bias = 0.040
#    - iteration: 4800 | loss (MSE) = 33198.163 | bias = 0.041
#    - iteration: 4900 | loss (MSE) = 33146.502 | bias = 0.041
#    - iteration: 5000 | loss (MSE) = 33097.113 | bias = 0.041
#    - iteration: 5100 | loss (MSE) = 33049.799 | bias = 0.042
#    - iteration: 5200 | loss (MSE) = 33004.382 | bias = 0.042
#    - iteration: 5300 | loss (MSE) = 32960.700 | bias = 0.043
#    - iteration: 5400 | loss (MSE) = 32918.606 | bias = 0.043
#    - iteration: 5500 | loss (MSE) = 32877.964 | bias = 0.043
#    - iteration: 5600 | loss (MSE) = 32838.651 | bias = 0.044
#    - iteration: 5700 | loss (MSE) = 32800.556 | bias = 0.044
#    - iteration: 5800 | loss (MSE) = 32763.577 | bias = 0.044
#    - iteration: 5900 | loss (MSE) = 32727.620 | bias = 0.045
#    - iteration: 6000 | loss (MSE) = 32692.600 | bias = 0.045
#    - iteration: 6100 | loss (MSE) = 32658.440 | bias = 0.045
#    - iteration: 6200 | loss (MSE) = 32625.070 | bias = 0.046
#    - iteration: 6300 | loss (MSE) = 32592.425 | bias = 0.046
#    - iteration: 6400 | loss (MSE) = 32560.447 | bias = 0.046
#    - iteration: 6500 | loss (MSE) = 32529.081 | bias = 0.047
#    - iteration: 6600 | loss (MSE) = 32498.280 | bias = 0.047
#    - iteration: 6700 | loss (MSE) = 32468.000 | bias = 0.047
#    - iteration: 6800 | loss (MSE) = 32438.198 | bias = 0.048
#    - iteration: 6900 | loss (MSE) = 32408.839 | bias = 0.048
#    - iteration: 7000 | loss (MSE) = 32379.889 | bias = 0.048
#    - iteration: 7100 | loss (MSE) = 32351.317 | bias = 0.049
#    - iteration: 7200 | loss (MSE) = 32323.096 | bias = 0.049
#    - iteration: 7300 | loss (MSE) = 32295.198 | bias = 0.049
#    - iteration: 7400 | loss (MSE) = 32267.602 | bias = 0.049
#    - iteration: 7500 | loss (MSE) = 32240.287 | bias = 0.050
#    - iteration: 7600 | loss (MSE) = 32213.231 | bias = 0.050
#    - iteration: 7700 | loss (MSE) = 32186.419 | bias = 0.050
#    - iteration: 7800 | loss (MSE) = 32159.834 | bias = 0.051
#    - iteration: 7900 | loss (MSE) = 32133.460 | bias = 0.051
#    - iteration: 8000 | loss (MSE) = 32107.286 | bias = 0.051
#    - iteration: 8100 | loss (MSE) = 32081.298 | bias = 0.051
#    - iteration: 8200 | loss (MSE) = 32055.485 | bias = 0.052
#    - iteration: 8300 | loss (MSE) = 32029.837 | bias = 0.052
#    - iteration: 8400 | loss (MSE) = 32004.346 | bias = 0.052
#    - iteration: 8500 | loss (MSE) = 31979.001 | bias = 0.052
#    - iteration: 8600 | loss (MSE) = 31953.796 | bias = 0.053
#    - iteration: 8700 | loss (MSE) = 31928.723 | bias = 0.053
#    - iteration: 8800 | loss (MSE) = 31903.777 | bias = 0.053
#    - iteration: 8900 | loss (MSE) = 31878.950 | bias = 0.053
#    - iteration: 9000 | loss (MSE) = 31854.238 | bias = 0.054
#    - iteration: 9100 | loss (MSE) = 31829.636 | bias = 0.054
#    - iteration: 9200 | loss (MSE) = 31805.139 | bias = 0.054
#    - iteration: 9300 | loss (MSE) = 31780.743 | bias = 0.054
#    - iteration: 9400 | loss (MSE) = 31756.444 | bias = 0.055
#    - iteration: 9500 | loss (MSE) = 31732.239 | bias = 0.055
#    - iteration: 9600 | loss (MSE) = 31708.125 | bias = 0.055
#    - iteration: 9700 | loss (MSE) = 31684.098 | bias = 0.056
#    - iteration: 9800 | loss (MSE) = 31660.157 | bias = 0.056
#    - iteration: 9900 | loss (MSE) = 31636.299 | bias = 0.056
# Treinamento Finalizado
# Iniciando treinamento( learning_rate = 1e-06 ):
#    - iteration: 0 | loss (MSE) = 58145.199 | bias = 0.000
#    - iteration: 100 | loss (MSE) = 43408.466 | bias = 0.015
#    - iteration: 200 | loss (MSE) = 37414.664 | bias = 0.025
#    - iteration: 300 | loss (MSE) = 34878.361 | bias = 0.032
#    - iteration: 400 | loss (MSE) = 33711.854 | bias = 0.037
#    - iteration: 500 | loss (MSE) = 33090.458 | bias = 0.042
#    - iteration: 600 | loss (MSE) = 32688.341 | bias = 0.045
#    - iteration: 700 | loss (MSE) = 32376.713 | bias = 0.048
#    - iteration: 800 | loss (MSE) = 32104.607 | bias = 0.051
#    - iteration: 900 | loss (MSE) = 31851.798 | bias = 0.054
#    - iteration: 1000 | loss (MSE) = 31610.208 | bias = 0.056
#    - iteration: 1100 | loss (MSE) = 31376.556 | bias = 0.059
#    - iteration: 1200 | loss (MSE) = 31149.457 | bias = 0.061
#    - iteration: 1300 | loss (MSE) = 30928.281 | bias = 0.063
#    - iteration: 1400 | loss (MSE) = 30712.695 | bias = 0.066
#    - iteration: 1500 | loss (MSE) = 30502.487 | bias = 0.068
#    - iteration: 1600 | loss (MSE) = 30297.495 | bias = 0.070
#    - iteration: 1700 | loss (MSE) = 30097.576 | bias = 0.073
#    - iteration: 1800 | loss (MSE) = 29902.601 | bias = 0.075
#    - iteration: 1900 | loss (MSE) = 29712.444 | bias = 0.077
#    - iteration: 2000 | loss (MSE) = 29526.985 | bias = 0.079
#    - iteration: 2100 | loss (MSE) = 29346.107 | bias = 0.081
#    - iteration: 2200 | loss (MSE) = 29169.695 | bias = 0.083
#    - iteration: 2300 | loss (MSE) = 28997.639 | bias = 0.086
#    - iteration: 2400 | loss (MSE) = 28829.830 | bias = 0.088
#    - iteration: 2500 | loss (MSE) = 28666.163 | bias = 0.090
#    - iteration: 2600 | loss (MSE) = 28506.534 | bias = 0.092
#    - iteration: 2700 | loss (MSE) = 28350.843 | bias = 0.094
#    - iteration: 2800 | loss (MSE) = 28198.992 | bias = 0.096
#    - iteration: 2900 | loss (MSE) = 28050.886 | bias = 0.098
#    - iteration: 3000 | loss (MSE) = 27906.431 | bias = 0.100
#    - iteration: 3100 | loss (MSE) = 27765.538 | bias = 0.102
#    - iteration: 3200 | loss (MSE) = 27628.116 | bias = 0.104
#    - iteration: 3300 | loss (MSE) = 27494.081 | bias = 0.106
#    - iteration: 3400 | loss (MSE) = 27363.347 | bias = 0.108
#    - iteration: 3500 | loss (MSE) = 27235.833 | bias = 0.110
#    - iteration: 3600 | loss (MSE) = 27111.460 | bias = 0.112
#    - iteration: 3700 | loss (MSE) = 26990.148 | bias = 0.114
#    - iteration: 3800 | loss (MSE) = 26871.821 | bias = 0.116
#    - iteration: 3900 | loss (MSE) = 26756.407 | bias = 0.118
#    - iteration: 4000 | loss (MSE) = 26643.832 | bias = 0.120
#    - iteration: 4100 | loss (MSE) = 26534.026 | bias = 0.121
#    - iteration: 4200 | loss (MSE) = 26426.920 | bias = 0.123
#    - iteration: 4300 | loss (MSE) = 26322.447 | bias = 0.125
#    - iteration: 4400 | loss (MSE) = 26220.542 | bias = 0.127
#    - iteration: 4500 | loss (MSE) = 26121.140 | bias = 0.129
#    - iteration: 4600 | loss (MSE) = 26024.181 | bias = 0.131
#    - iteration: 4700 | loss (MSE) = 25929.603 | bias = 0.132
#    - iteration: 4800 | loss (MSE) = 25837.348 | bias = 0.134
#    - iteration: 4900 | loss (MSE) = 25747.357 | bias = 0.136
#    - iteration: 5000 | loss (MSE) = 25659.574 | bias = 0.138
#    - iteration: 5100 | loss (MSE) = 25573.946 | bias = 0.140
#    - iteration: 5200 | loss (MSE) = 25490.417 | bias = 0.141
#    - iteration: 5300 | loss (MSE) = 25408.937 | bias = 0.143
#    - iteration: 5400 | loss (MSE) = 25329.454 | bias = 0.145
#    - iteration: 5500 | loss (MSE) = 25251.920 | bias = 0.146
#    - iteration: 5600 | loss (MSE) = 25176.285 | bias = 0.148
#    - iteration: 5700 | loss (MSE) = 25102.503 | bias = 0.150
#    - iteration: 5800 | loss (MSE) = 25030.527 | bias = 0.152
#    - iteration: 5900 | loss (MSE) = 24960.314 | bias = 0.153
#    - iteration: 6000 | loss (MSE) = 24891.818 | bias = 0.155
#    - iteration: 6100 | loss (MSE) = 24824.999 | bias = 0.157
#    - iteration: 6200 | loss (MSE) = 24759.814 | bias = 0.158
#    - iteration: 6300 | loss (MSE) = 24696.223 | bias = 0.160
#    - iteration: 6400 | loss (MSE) = 24634.186 | bias = 0.161
#    - iteration: 6500 | loss (MSE) = 24573.665 | bias = 0.163
#    - iteration: 6600 | loss (MSE) = 24514.623 | bias = 0.165
#    - iteration: 6700 | loss (MSE) = 24457.022 | bias = 0.166
#    - iteration: 6800 | loss (MSE) = 24400.828 | bias = 0.168
#    - iteration: 6900 | loss (MSE) = 24346.005 | bias = 0.170
#    - iteration: 7000 | loss (MSE) = 24292.519 | bias = 0.171
#    - iteration: 7100 | loss (MSE) = 24240.338 | bias = 0.173
#    - iteration: 7200 | loss (MSE) = 24189.429 | bias = 0.174
#    - iteration: 7300 | loss (MSE) = 24139.761 | bias = 0.176
#    - iteration: 7400 | loss (MSE) = 24091.303 | bias = 0.177
#    - iteration: 7500 | loss (MSE) = 24044.025 | bias = 0.179
#    - iteration: 7600 | loss (MSE) = 23997.898 | bias = 0.180
#    - iteration: 7700 | loss (MSE) = 23952.894 | bias = 0.182
#    - iteration: 7800 | loss (MSE) = 23908.985 | bias = 0.183
#    - iteration: 7900 | loss (MSE) = 23866.143 | bias = 0.185
#    - iteration: 8000 | loss (MSE) = 23824.343 | bias = 0.186
#    - iteration: 8100 | loss (MSE) = 23783.558 | bias = 0.188
#    - iteration: 8200 | loss (MSE) = 23743.764 | bias = 0.189
#    - iteration: 8300 | loss (MSE) = 23704.937 | bias = 0.191
#    - iteration: 8400 | loss (MSE) = 23667.052 | bias = 0.192
#    - iteration: 8500 | loss (MSE) = 23630.085 | bias = 0.194
#    - iteration: 8600 | loss (MSE) = 23594.016 | bias = 0.195
#    - iteration: 8700 | loss (MSE) = 23558.821 | bias = 0.197
#    - iteration: 8800 | loss (MSE) = 23524.478 | bias = 0.198
#    - iteration: 8900 | loss (MSE) = 23490.968 | bias = 0.200
#    - iteration: 9000 | loss (MSE) = 23458.268 | bias = 0.201
#    - iteration: 9100 | loss (MSE) = 23426.360 | bias = 0.203
#    - iteration: 9200 | loss (MSE) = 23395.224 | bias = 0.204
#    - iteration: 9300 | loss (MSE) = 23364.841 | bias = 0.205
#    - iteration: 9400 | loss (MSE) = 23335.192 | bias = 0.207
#    - iteration: 9500 | loss (MSE) = 23306.259 | bias = 0.208
#    - iteration: 9600 | loss (MSE) = 23278.024 | bias = 0.210
#    - iteration: 9700 | loss (MSE) = 23250.471 | bias = 0.211
#    - iteration: 9800 | loss (MSE) = 23223.583 | bias = 0.212
#    - iteration: 9900 | loss (MSE) = 23197.343 | bias = 0.214
# Treinamento Finalizado
# Iniciando treinamento( learning_rate = 1e-05 ):
#    - iteration: 0 | loss (MSE) = 56160.143 | bias = 0.002
#    - iteration: 100 | loss (MSE) = 31587.175 | bias = 0.057
#    - iteration: 200 | loss (MSE) = 29508.452 | bias = 0.079
#    - iteration: 300 | loss (MSE) = 27891.199 | bias = 0.100
#    - iteration: 400 | loss (MSE) = 26631.343 | bias = 0.120
#    - iteration: 500 | loss (MSE) = 25649.357 | bias = 0.138
#    - iteration: 600 | loss (MSE) = 24883.475 | bias = 0.155
#    - iteration: 700 | loss (MSE) = 24285.717 | bias = 0.171
#    - iteration: 800 | loss (MSE) = 23818.804 | bias = 0.187
#    - iteration: 900 | loss (MSE) = 23453.764 | bias = 0.201
#    - iteration: 1000 | loss (MSE) = 23168.075 | bias = 0.215
#    - iteration: 1100 | loss (MSE) = 22944.223 | bias = 0.229
#    - iteration: 1200 | loss (MSE) = 22768.588 | bias = 0.242
#    - iteration: 1300 | loss (MSE) = 22630.568 | bias = 0.254
#    - iteration: 1400 | loss (MSE) = 22521.913 | bias = 0.266
#    - iteration: 1500 | loss (MSE) = 22436.197 | bias = 0.278
#    - iteration: 1600 | loss (MSE) = 22368.415 | bias = 0.289
#    - iteration: 1700 | loss (MSE) = 22314.664 | bias = 0.301
#    - iteration: 1800 | loss (MSE) = 22271.902 | bias = 0.312
#    - iteration: 1900 | loss (MSE) = 22237.752 | bias = 0.322
#    - iteration: 2000 | loss (MSE) = 22210.360 | bias = 0.333
#    - iteration: 2100 | loss (MSE) = 22188.277 | bias = 0.343
#    - iteration: 2200 | loss (MSE) = 22170.370 | bias = 0.354
#    - iteration: 2300 | loss (MSE) = 22155.750 | bias = 0.364
#    - iteration: 2400 | loss (MSE) = 22143.724 | bias = 0.374
#    - iteration: 2500 | loss (MSE) = 22133.745 | bias = 0.384
#    - iteration: 2600 | loss (MSE) = 22125.387 | bias = 0.394
#    - iteration: 2700 | loss (MSE) = 22118.311 | bias = 0.404
#    - iteration: 2800 | loss (MSE) = 22112.255 | bias = 0.414
#    - iteration: 2900 | loss (MSE) = 22107.009 | bias = 0.424
#    - iteration: 3000 | loss (MSE) = 22102.409 | bias = 0.433
#    - iteration: 3100 | loss (MSE) = 22098.324 | bias = 0.443
#    - iteration: 3200 | loss (MSE) = 22094.652 | bias = 0.453
#    - iteration: 3300 | loss (MSE) = 22091.310 | bias = 0.462
#    - iteration: 3400 | loss (MSE) = 22088.235 | bias = 0.472
#    - iteration: 3500 | loss (MSE) = 22085.374 | bias = 0.481
#    - iteration: 3600 | loss (MSE) = 22082.687 | bias = 0.491
#    - iteration: 3700 | loss (MSE) = 22080.140 | bias = 0.501
#    - iteration: 3800 | loss (MSE) = 22077.706 | bias = 0.510
#    - iteration: 3900 | loss (MSE) = 22075.366 | bias = 0.520
#    - iteration: 4000 | loss (MSE) = 22073.102 | bias = 0.529
#    - iteration: 4100 | loss (MSE) = 22070.899 | bias = 0.539
#    - iteration: 4200 | loss (MSE) = 22068.748 | bias = 0.548
#    - iteration: 4300 | loss (MSE) = 22066.638 | bias = 0.558
#    - iteration: 4400 | loss (MSE) = 22064.564 | bias = 0.567
#    - iteration: 4500 | loss (MSE) = 22062.518 | bias = 0.576
#    - iteration: 4600 | loss (MSE) = 22060.496 | bias = 0.586
#    - iteration: 4700 | loss (MSE) = 22058.494 | bias = 0.595
#    - iteration: 4800 | loss (MSE) = 22056.509 | bias = 0.605
#    - iteration: 4900 | loss (MSE) = 22054.537 | bias = 0.614
#    - iteration: 5000 | loss (MSE) = 22052.578 | bias = 0.624
#    - iteration: 5100 | loss (MSE) = 22050.628 | bias = 0.633
#    - iteration: 5200 | loss (MSE) = 22048.687 | bias = 0.643
#    - iteration: 5300 | loss (MSE) = 22046.752 | bias = 0.652
#    - iteration: 5400 | loss (MSE) = 22044.824 | bias = 0.662
#    - iteration: 5500 | loss (MSE) = 22042.902 | bias = 0.671
#    - iteration: 5600 | loss (MSE) = 22040.984 | bias = 0.680
#    - iteration: 5700 | loss (MSE) = 22039.069 | bias = 0.690
#    - iteration: 5800 | loss (MSE) = 22037.158 | bias = 0.699
#    - iteration: 5900 | loss (MSE) = 22035.250 | bias = 0.709
#    - iteration: 6000 | loss (MSE) = 22033.345 | bias = 0.718
#    - iteration: 6100 | loss (MSE) = 22031.442 | bias = 0.728
#    - iteration: 6200 | loss (MSE) = 22029.541 | bias = 0.737
#    - iteration: 6300 | loss (MSE) = 22027.642 | bias = 0.746
#    - iteration: 6400 | loss (MSE) = 22025.744 | bias = 0.756
#    - iteration: 6500 | loss (MSE) = 22023.848 | bias = 0.765
#    - iteration: 6600 | loss (MSE) = 22021.953 | bias = 0.775
#    - iteration: 6700 | loss (MSE) = 22020.060 | bias = 0.784
#    - iteration: 6800 | loss (MSE) = 22018.167 | bias = 0.793
#    - iteration: 6900 | loss (MSE) = 22016.276 | bias = 0.803
#    - iteration: 7000 | loss (MSE) = 22014.386 | bias = 0.812
#    - iteration: 7100 | loss (MSE) = 22012.497 | bias = 0.822
#    - iteration: 7200 | loss (MSE) = 22010.608 | bias = 0.831
#    - iteration: 7300 | loss (MSE) = 22008.720 | bias = 0.840
#    - iteration: 7400 | loss (MSE) = 22006.834 | bias = 0.850
#    - iteration: 7500 | loss (MSE) = 22004.948 | bias = 0.859
#    - iteration: 7600 | loss (MSE) = 22003.062 | bias = 0.869
# ...
#    - iteration: 1300 | loss (MSE) = nan | bias = nan
#    - iteration: 1400 | loss (MSE) = nan | bias = nan
#    - iteration: 1500 | loss (MSE) = nan | bias = nan
#    - iteration: 1600 | loss (MSE) = nan | bias = nan
#    - iteration: 1700 | loss (MSE) = nan | bias = nan
#    - iteration: 1800 | loss (MSE) = nan | bias = nan
#    - iteration: 1900 | loss (MSE) = nan | bias = nan
#    - iteration: 2000 | loss (MSE) = nan | bias = nan
#    - iteration: 2100 | loss (MSE) = nan | bias = nan
#    - iteration: 2200 | loss (MSE) = nan | bias = nan
#    - iteration: 2300 | loss (MSE) = nan | bias = nan
#    - iteration: 2400 | loss (MSE) = nan | bias = nan
#    - iteration: 2500 | loss (MSE) = nan | bias = nan
#    - iteration: 2600 | loss (MSE) = nan | bias = nan
#    - iteration: 2700 | loss (MSE) = nan | bias = nan
#    - iteration: 2800 | loss (MSE) = nan | bias = nan
#    - iteration: 2900 | loss (MSE) = nan | bias = nan
#    - iteration: 3000 | loss (MSE) = nan | bias = nan
#    - iteration: 3100 | loss (MSE) = nan | bias = nan
#    - iteration: 3200 | loss (MSE) = nan | bias = nan
#    - iteration: 3300 | loss (MSE) = nan | bias = nan
#    - iteration: 3400 | loss (MSE) = nan | bias = nan
#    - iteration: 3500 | loss (MSE) = nan | bias = nan
#    - iteration: 3600 | loss (MSE) = nan | bias = nan
#    - iteration: 3700 | loss (MSE) = nan | bias = nan
#    - iteration: 3800 | loss (MSE) = nan | bias = nan
#    - iteration: 3900 | loss (MSE) = nan | bias = nan
#    - iteration: 4000 | loss (MSE) = nan | bias = nan
#    - iteration: 4100 | loss (MSE) = nan | bias = nan
#    - iteration: 4200 | loss (MSE) = nan | bias = nan
#    - iteration: 4300 | loss (MSE) = nan | bias = nan
#    - iteration: 4400 | loss (MSE) = nan | bias = nan
#    - iteration: 4500 | loss (MSE) = nan | bias = nan
#    - iteration: 4600 | loss (MSE) = nan | bias = nan
#    - iteration: 4700 | loss (MSE) = nan | bias = nan
#    - iteration: 4800 | loss (MSE) = nan | bias = nan
#    - iteration: 4900 | loss (MSE) = nan | bias = nan
#    - iteration: 5000 | loss (MSE) = nan | bias = nan
#    - iteration: 5100 | loss (MSE) = nan | bias = nan
#    - iteration: 5200 | loss (MSE) = nan | bias = nan
#    - iteration: 5300 | loss (MSE) = nan | bias = nan
#    - iteration: 5400 | loss (MSE) = nan | bias = nan
#    - iteration: 5500 | loss (MSE) = nan | bias = nan
#    - iteration: 5600 | loss (MSE) = nan | bias = nan
#    - iteration: 5700 | loss (MSE) = nan | bias = nan
#    - iteration: 5800 | loss (MSE) = nan | bias = nan
#    - iteration: 5900 | loss (MSE) = nan | bias = nan
#    - iteration: 6000 | loss (MSE) = nan | bias = nan
#    - iteration: 6100 | loss (MSE) = nan | bias = nan
#    - iteration: 6200 | loss (MSE) = nan | bias = nan
#    - iteration: 6300 | loss (MSE) = nan | bias = nan
#    - iteration: 6400 | loss (MSE) = nan | bias = nan
#    - iteration: 6500 | loss (MSE) = nan | bias = nan
#    - iteration: 6600 | loss (MSE) = nan | bias = nan
#    - iteration: 6700 | loss (MSE) = nan | bias = nan
#    - iteration: 6800 | loss (MSE) = nan | bias = nan
#    - iteration: 6900 | loss (MSE) = nan | bias = nan
#    - iteration: 7000 | loss (MSE) = nan | bias = nan
#    - iteration: 7100 | loss (MSE) = nan | bias = nan
#    - iteration: 7200 | loss (MSE) = nan | bias = nan
#    - iteration: 7300 | loss (MSE) = nan | bias = nan
#    - iteration: 7400 | loss (MSE) = nan | bias = nan
#    - iteration: 7500 | loss (MSE) = nan | bias = nan
#    - iteration: 7600 | loss (MSE) = nan | bias = nan
#    - iteration: 7700 | loss (MSE) = nan | bias = nan
#    - iteration: 7800 | loss (MSE) = nan | bias = nan
#    - iteration: 7900 | loss (MSE) = nan | bias = nan
#    - iteration: 8000 | loss (MSE) = nan | bias = nan
#    - iteration: 8100 | loss (MSE) = nan | bias = nan
#    - iteration: 8200 | loss (MSE) = nan | bias = nan
#    - iteration: 8300 | loss (MSE) = nan | bias = nan
#    - iteration: 8400 | loss (MSE) = nan | bias = nan
#    - iteration: 8500 | loss (MSE) = nan | bias = nan
#    - iteration: 8600 | loss (MSE) = nan | bias = nan
#    - iteration: 8700 | loss (MSE) = nan | bias = nan
#    - iteration: 8800 | loss (MSE) = nan | bias = nan
#    - iteration: 8900 | loss (MSE) = nan | bias = nan
#    - iteration: 9000 | loss (MSE) = nan | bias = nan
#    - iteration: 9100 | loss (MSE) = nan | bias = nan
#    - iteration: 9200 | loss (MSE) = nan | bias = nan
#    - iteration: 9300 | loss (MSE) = nan | bias = nan
#    - iteration: 9400 | loss (MSE) = nan | bias = nan
#    - iteration: 9500 | loss (MSE) = nan | bias = nan
#    - iteration: 9600 | loss (MSE) = nan | bias = nan
#    - iteration: 9700 | loss (MSE) = nan | bias = nan
#    - iteration: 9800 | loss (MSE) = nan | bias = nan
#    - iteration: 9900 | loss (MSE) = nan | bias = nan
# Treinamento Finalizado
# Iniciando treinamento( learning_rate = 0.01 ):
#    - iteration: 0 | loss (MSE) = 49536510.842 | bias = 1.746
#    - iteration: 100 | loss (MSE) = inf | bias = 6488294461965048699860702512469115193744470812747192301630516207295568819586391380664025564056290947668662759179520439700829175143108842987925263964080184798518181888.000
#    - iteration: 200 | loss (MSE) = nan | bias = nan
#    - iteration: 300 | loss (MSE) = nan | bias = nan
# /tmp/ipykernel_18426/913609493.py:102: RuntimeWarning: invalid value encountered in matmul
#   return X @ self.weights + self.bias # Dot product
#    - iteration: 400 | loss (MSE) = nan | bias = nan
#    - iteration: 500 | loss (MSE) = nan | bias = nan
#    - iteration: 600 | loss (MSE) = nan | bias = nan
#    - iteration: 700 | loss (MSE) = nan | bias = nan
#    - iteration: 800 | loss (MSE) = nan | bias = nan
#    - iteration: 900 | loss (MSE) = nan | bias = nan
#    - iteration: 1000 | loss (MSE) = nan | bias = nan
#    - iteration: 1100 | loss (MSE) = nan | bias = nan
#    - iteration: 1200 | loss (MSE) = nan | bias = nan
#    - iteration: 1300 | loss (MSE) = nan | bias = nan
#    - iteration: 1400 | loss (MSE) = nan | bias = nan
#    - iteration: 1500 | loss (MSE) = nan | bias = nan
#    - iteration: 1600 | loss (MSE) = nan | bias = nan
#    - iteration: 1700 | loss (MSE) = nan | bias = nan
#    - iteration: 1800 | loss (MSE) = nan | bias = nan
#    - iteration: 1900 | loss (MSE) = nan | bias = nan
#    - iteration: 2000 | loss (MSE) = nan | bias = nan
#    - iteration: 2100 | loss (MSE) = nan | bias = nan
#    - iteration: 2200 | loss (MSE) = nan | bias = nan
#    - iteration: 2300 | loss (MSE) = nan | bias = nan
#    - iteration: 2400 | loss (MSE) = nan | bias = nan
#    - iteration: 2500 | loss (MSE) = nan | bias = nan
#    - iteration: 2600 | loss (MSE) = nan | bias = nan
#    - iteration: 2700 | loss (MSE) = nan | bias = nan
#    - iteration: 2800 | loss (MSE) = nan | bias = nan
#    - iteration: 2900 | loss (MSE) = nan | bias = nan
#    - iteration: 3000 | loss (MSE) = nan | bias = nan
#    - iteration: 3100 | loss (MSE) = nan | bias = nan
#    - iteration: 3200 | loss (MSE) = nan | bias = nan
#    - iteration: 3300 | loss (MSE) = nan | bias = nan
#    - iteration: 3400 | loss (MSE) = nan | bias = nan
#    - iteration: 3500 | loss (MSE) = nan | bias = nan
#    - iteration: 3600 | loss (MSE) = nan | bias = nan
#    - iteration: 3700 | loss (MSE) = nan | bias = nan
#    - iteration: 3800 | loss (MSE) = nan | bias = nan
#    - iteration: 3900 | loss (MSE) = nan | bias = nan
#    - iteration: 4000 | loss (MSE) = nan | bias = nan
#    - iteration: 4100 | loss (MSE) = nan | bias = nan
#    - iteration: 4200 | loss (MSE) = nan | bias = nan
#    - iteration: 4300 | loss (MSE) = nan | bias = nan
#    - iteration: 4400 | loss (MSE) = nan | bias = nan
#    - iteration: 4500 | loss (MSE) = nan | bias = nan
#    - iteration: 4600 | loss (MSE) = nan | bias = nan
#    - iteration: 4700 | loss (MSE) = nan | bias = nan
#    - iteration: 4800 | loss (MSE) = nan | bias = nan
#    - iteration: 4900 | loss (MSE) = nan | bias = nan
#    - iteration: 5000 | loss (MSE) = nan | bias = nan
#    - iteration: 5100 | loss (MSE) = nan | bias = nan
#    - iteration: 5200 | loss (MSE) = nan | bias = nan
#    - iteration: 5300 | loss (MSE) = nan | bias = nan
#    - iteration: 5400 | loss (MSE) = nan | bias = nan
#    - iteration: 5500 | loss (MSE) = nan | bias = nan
#    - iteration: 5600 | loss (MSE) = nan | bias = nan
#    - iteration: 5700 | loss (MSE) = nan | bias = nan
#    - iteration: 5800 | loss (MSE) = nan | bias = nan
#    - iteration: 5900 | loss (MSE) = nan | bias = nan
#    - iteration: 6000 | loss (MSE) = nan | bias = nan
#    - iteration: 6100 | loss (MSE) = nan | bias = nan
#    - iteration: 6200 | loss (MSE) = nan | bias = nan
#    - iteration: 6300 | loss (MSE) = nan | bias = nan
#    - iteration: 6400 | loss (MSE) = nan | bias = nan
#    - iteration: 6500 | loss (MSE) = nan | bias = nan
#    - iteration: 6600 | loss (MSE) = nan | bias = nan
#    - iteration: 6700 | loss (MSE) = nan | bias = nan
#    - iteration: 6800 | loss (MSE) = nan | bias = nan
#    - iteration: 6900 | loss (MSE) = nan | bias = nan
#    - iteration: 7000 | loss (MSE) = nan | bias = nan
#    - iteration: 7100 | loss (MSE) = nan | bias = nan
#    - iteration: 7200 | loss (MSE) = nan | bias = nan
#    - iteration: 7300 | loss (MSE) = nan | bias = nan
#    - iteration: 7400 | loss (MSE) = nan | bias = nan
#    - iteration: 7500 | loss (MSE) = nan | bias = nan
#    - iteration: 7600 | loss (MSE) = nan | bias = nan
#    - iteration: 7700 | loss (MSE) = nan | bias = nan
#    - iteration: 7800 | loss (MSE) = nan | bias = nan
#    - iteration: 7900 | loss (MSE) = nan | bias = nan
#    - iteration: 8000 | loss (MSE) = nan | bias = nan
#    - iteration: 8100 | loss (MSE) = nan | bias = nan
#    - iteration: 8200 | loss (MSE) = nan | bias = nan
#    - iteration: 8300 | loss (MSE) = nan | bias = nan
#    - iteration: 8400 | loss (MSE) = nan | bias = nan
#    - iteration: 8500 | loss (MSE) = nan | bias = nan
#    - iteration: 8600 | loss (MSE) = nan | bias = nan
#    - iteration: 8700 | loss (MSE) = nan | bias = nan
#    - iteration: 8800 | loss (MSE) = nan | bias = nan
#    - iteration: 8900 | loss (MSE) = nan | bias = nan
#    - iteration: 9000 | loss (MSE) = nan | bias = nan
#    - iteration: 9100 | loss (MSE) = nan | bias = nan
#    - iteration: 9200 | loss (MSE) = nan | bias = nan
#    - iteration: 9300 | loss (MSE) = nan | bias = nan
#    - iteration: 9400 | loss (MSE) = nan | bias = nan
#    - iteration: 9500 | loss (MSE) = nan | bias = nan
#    - iteration: 9600 | loss (MSE) = nan | bias = nan
#    - iteration: 9700 | loss (MSE) = nan | bias = nan
#    - iteration: 9800 | loss (MSE) = nan | bias = nan
#    - iteration: 9900 | loss (MSE) = nan | bias = nan
# Treinamento Finalizado
# Iniciando treinamento( learning_rate = 0.1 ):
#    - iteration: 0 | loss (MSE) = 5151500299.158 | bias = 17.464
#    - iteration: 100 | loss (MSE) = inf | bias = .000
#    - iteration: 200 | loss (MSE) = nan | bias = nan
#    - iteration: 300 | loss (MSE) = nan | bias = nan
#    - iteration: 400 | loss (MSE) = nan | bias = nan
#    - iteration: 500 | loss (MSE) = nan | bias = nan
#    - iteration: 600 | loss (MSE) = nan | bias = nan
#    - iteration: 700 | loss (MSE) = nan | bias = nan
#    - iteration: 800 | loss (MSE) = nan | bias = nan
#    - iteration: 900 | loss (MSE) = nan | bias = nan
#    - iteration: 1000 | loss (MSE) = nan | bias = nan
#    - iteration: 1100 | loss (MSE) = nan | bias = nan
#    - iteration: 1200 | loss (MSE) = nan | bias = nan
#    - iteration: 1300 | loss (MSE) = nan | bias = nan
#    - iteration: 1400 | loss (MSE) = nan | bias = nan
#    - iteration: 1500 | loss (MSE) = nan | bias = nan
#    - iteration: 1600 | loss (MSE) = nan | bias = nan
#    - iteration: 1700 | loss (MSE) = nan | bias = nan
#    - iteration: 1800 | loss (MSE) = nan | bias = nan
#    - iteration: 1900 | loss (MSE) = nan | bias = nan
#    - iteration: 2000 | loss (MSE) = nan | bias = nan
#    - iteration: 2100 | loss (MSE) = nan | bias = nan
#    - iteration: 2200 | loss (MSE) = nan | bias = nan
#    - iteration: 2300 | loss (MSE) = nan | bias = nan
#    - iteration: 2400 | loss (MSE) = nan | bias = nan
#    - iteration: 2500 | loss (MSE) = nan | bias = nan
#    - iteration: 2600 | loss (MSE) = nan | bias = nan
#    - iteration: 2700 | loss (MSE) = nan | bias = nan
#    - iteration: 2800 | loss (MSE) = nan | bias = nan
#    - iteration: 2900 | loss (MSE) = nan | bias = nan
#    - iteration: 3000 | loss (MSE) = nan | bias = nan
#    - iteration: 3100 | loss (MSE) = nan | bias = nan
#    - iteration: 3200 | loss (MSE) = nan | bias = nan
#    - iteration: 3300 | loss (MSE) = nan | bias = nan
#    - iteration: 3400 | loss (MSE) = nan | bias = nan
#    - iteration: 3500 | loss (MSE) = nan | bias = nan
#    - iteration: 3600 | loss (MSE) = nan | bias = nan
#    - iteration: 3700 | loss (MSE) = nan | bias = nan
#    - iteration: 3800 | loss (MSE) = nan | bias = nan
#    - iteration: 3900 | loss (MSE) = nan | bias = nan
#    - iteration: 4000 | loss (MSE) = nan | bias = nan
#    - iteration: 4100 | loss (MSE) = nan | bias = nan
#    - iteration: 4200 | loss (MSE) = nan | bias = nan
#    - iteration: 4300 | loss (MSE) = nan | bias = nan
#    - iteration: 4400 | loss (MSE) = nan | bias = nan
#    - iteration: 4500 | loss (MSE) = nan | bias = nan
#    - iteration: 4600 | loss (MSE) = nan | bias = nan
#    - iteration: 4700 | loss (MSE) = nan | bias = nan
#    - iteration: 4800 | loss (MSE) = nan | bias = nan
#    - iteration: 4900 | loss (MSE) = nan | bias = nan
#    - iteration: 5000 | loss (MSE) = nan | bias = nan
#    - iteration: 5100 | loss (MSE) = nan | bias = nan
#    - iteration: 5200 | loss (MSE) = nan | bias = nan
#    - iteration: 5300 | loss (MSE) = nan | bias = nan
#    - iteration: 5400 | loss (MSE) = nan | bias = nan
#    - iteration: 5500 | loss (MSE) = nan | bias = nan
#    - iteration: 5600 | loss (MSE) = nan | bias = nan
#    - iteration: 5700 | loss (MSE) = nan | bias = nan
#    - iteration: 5800 | loss (MSE) = nan | bias = nan
#    - iteration: 5900 | loss (MSE) = nan | bias = nan
#    - iteration: 6000 | loss (MSE) = nan | bias = nan
#    - iteration: 6100 | loss (MSE) = nan | bias = nan
#    - iteration: 6200 | loss (MSE) = nan | bias = nan
#    - iteration: 6300 | loss (MSE) = nan | bias = nan
#    - iteration: 6400 | loss (MSE) = nan | bias = nan
#    - iteration: 6500 | loss (MSE) = nan | bias = nan
#    - iteration: 6600 | loss (MSE) = nan | bias = nan
#    - iteration: 6700 | loss (MSE) = nan | bias = nan
#    - iteration: 6800 | loss (MSE) = nan | bias = nan
#    - iteration: 6900 | loss (MSE) = nan | bias = nan
#    - iteration: 7000 | loss (MSE) = nan | bias = nan
#    - iteration: 7100 | loss (MSE) = nan | bias = nan
#    - iteration: 7200 | loss (MSE) = nan | bias = nan
#    - iteration: 7300 | loss (MSE) = nan | bias = nan
#    - iteration: 7400 | loss (MSE) = nan | bias = nan
#    - iteration: 7500 | loss (MSE) = nan | bias = nan
#    - iteration: 7600 | loss (MSE) = nan | bias = nan
#    - iteration: 7700 | loss (MSE) = nan | bias = nan
#    - iteration: 7800 | loss (MSE) = nan | bias = nan
#    - iteration: 7900 | loss (MSE) = nan | bias = nan
#    - iteration: 8000 | loss (MSE) = nan | bias = nan
#    - iteration: 8100 | loss (MSE) = nan | bias = nan
#    - iteration: 8200 | loss (MSE) = nan | bias = nan
#    - iteration: 8300 | loss (MSE) = nan | bias = nan
#    - iteration: 8400 | loss (MSE) = nan | bias = nan
#    - iteration: 8500 | loss (MSE) = nan | bias = nan
#    - iteration: 8600 | loss (MSE) = nan | bias = nan
#    - iteration: 8700 | loss (MSE) = nan | bias = nan
#    - iteration: 8800 | loss (MSE) = nan | bias = nan
#    - iteration: 8900 | loss (MSE) = nan | bias = nan
#    - iteration: 9000 | loss (MSE) = nan | bias = nan
#    - iteration: 9100 | loss (MSE) = nan | bias = nan
#    - iteration: 9200 | loss (MSE) = nan | bias = nan
#    - iteration: 9300 | loss (MSE) = nan | bias = nan
#    - iteration: 9400 | loss (MSE) = nan | bias = nan
#    - iteration: 9500 | loss (MSE) = nan | bias = nan
#    - iteration: 9600 | loss (MSE) = nan | bias = nan
#    - iteration: 9700 | loss (MSE) = nan | bias = nan
#    - iteration: 9800 | loss (MSE) = nan | bias = nan
#    - iteration: 9900 | loss (MSE) = nan | bias = nan
# Treinamento Finalizado

# %% [markdown]
# > **Question:**
# >
# > How did the model perform for different learning rates?
# > What happened when the learning rate was too small or too large?
# >
# > Interpret the metric values obtained.
# Is the prediction error small relative to the scale of the target variable?
# >
# > Propose at least one hypothesis explaining the observed error.

# %% [markdown]
# Com Learning rates muito pequenas, o modelo teve um erro muito grande que se manteram relativamente constantes na faixa de 10⁻12 a 10⁻9. Nesses casos, a taxa de aprendizado não foi suficiente para atualizar os pesos utilizando o gradiente, gerando, a cada alteração, pouca ou nenhuma mudança (Como pode ser visto nos valores do MSE de treinamento). No outro extremo, para taxas de aprendizado pequenas (de 10⁻4 a 10⁻1) o modelo não convergiu, possivelmente devido a atualizações muito grandes dos pesos que levavam a um overshotting do gradiente

# %% [markdown]
# ---
# ### **Visualizing Predictions**
#
# (1.0 points) Numerical metrics summarize model quality, but visual diagnostics reveal structural problems that scalar measures may hide. Two standard visual tools are the predicted vs. observed plot and the Q–Q plot of residuals.
#
# Choose a model from the previous session to analyse further here.
#
# #### **Predicted vs. Observed Plot**
#
# A direct way to evaluate prediction quality is to compare the predicted values with the true observations.
# For each sample, plot the pair `(y, y_pred)`, the ideal predictor would have
# perfectly match predictions, yielding all points in the line y = x in the graph.
#
# However, this is often not the case, as prediction can go wrong.
# This plot help us interpret points that are closer to the x=y line as better
# predictions, and points further from this line as bad predictions.
#
# If the overall shape of the points does not follow the line, we may have a
# **systematic error**, indicating model misspecification.
#
# By coloring each point by some other characteristic, we can also see if the error
# is systematic with respect to that characteristic.
# For example, the model mispredicts some seaons more than others.
#
# You can explore more plots to get an insight on why and how is your model fit.

# %%
def pred_vs_true_plot(y_true: NDArray[np.float64], y_pred: NDArray[np.float64]) -> None:
    _, ax = plt.subplots(figsize=(10, 6))

    ax.grid()
    ax.scatter(y_true, y_pred, alpha=0.5)
    ax.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], color='red', linestyle='--', label='Ideal Fit')
    ax.set_xlabel("True Values")
    ax.set_ylabel("Predicted Values")
    ax.set_title("Predicted vs True Values")
    ax.grid(True)
    ax.legend()
    plt.show()

# %%
best_lr = 1e-5 # Choose the best learning rate based on the previous graphs

best_linear_model = LinearRegression(learning_rate=best_lr, n_iterations=10000)
best_linear_model.fit(X, y)
y_pred = best_linear_model.predict(X)

pred_vs_true_plot(y, y_pred)
# Out:
# Iniciando treinamento( learning_rate = 1e-05 ):
#    - iteration: 0 | loss (MSE) = 28143.304 | bias = 0.002
#    - iteration: 100 | loss (MSE) = 25845.538 | bias = 0.019
#    - iteration: 200 | loss (MSE) = 24819.889 | bias = 0.035
#    - iteration: 300 | loss (MSE) = 23988.189 | bias = 0.049
#    - iteration: 400 | loss (MSE) = 23310.918 | bias = 0.062
#    - iteration: 500 | loss (MSE) = 22758.978 | bias = 0.075
#    - iteration: 600 | loss (MSE) = 22308.930 | bias = 0.087
#    - iteration: 700 | loss (MSE) = 21941.757 | bias = 0.098
#    - iteration: 800 | loss (MSE) = 21642.018 | bias = 0.109
#    - iteration: 900 | loss (MSE) = 21397.169 | bias = 0.119
#    - iteration: 1000 | loss (MSE) = 21197.016 | bias = 0.129
#    - iteration: 1100 | loss (MSE) = 21033.276 | bias = 0.139
#    - iteration: 1200 | loss (MSE) = 20899.214 | bias = 0.148
#    - iteration: 1300 | loss (MSE) = 20789.349 | bias = 0.157
#    - iteration: 1400 | loss (MSE) = 20699.226 | bias = 0.166
#    - iteration: 1500 | loss (MSE) = 20625.215 | bias = 0.175
#    - iteration: 1600 | loss (MSE) = 20564.362 | bias = 0.183
#    - iteration: 1700 | loss (MSE) = 20514.260 | bias = 0.191
#    - iteration: 1800 | loss (MSE) = 20472.948 | bias = 0.199
#    - iteration: 1900 | loss (MSE) = 20438.826 | bias = 0.207
#    - iteration: 2000 | loss (MSE) = 20410.590 | bias = 0.215
#    - iteration: 2100 | loss (MSE) = 20387.175 | bias = 0.223
#    - iteration: 2200 | loss (MSE) = 20367.711 | bias = 0.230
#    - iteration: 2300 | loss (MSE) = 20351.488 | bias = 0.237
#    - iteration: 2400 | loss (MSE) = 20337.924 | bias = 0.245
#    - iteration: 2500 | loss (MSE) = 20326.546 | bias = 0.252
#    - iteration: 2600 | loss (MSE) = 20316.963 | bias = 0.259
#    - iteration: 2700 | loss (MSE) = 20308.858 | bias = 0.266
#    - iteration: 2800 | loss (MSE) = 20301.969 | bias = 0.273
#    - iteration: 2900 | loss (MSE) = 20296.082 | bias = 0.280
#    - iteration: 3000 | loss (MSE) = 20291.022 | bias = 0.287
#    - iteration: 3100 | loss (MSE) = 20286.644 | bias = 0.294
#    - iteration: 3200 | loss (MSE) = 20282.830 | bias = 0.301
#    - iteration: 3300 | loss (MSE) = 20279.482 | bias = 0.308
#    - iteration: 3400 | loss (MSE) = 20276.519 | bias = 0.315
#    - iteration: 3500 | loss (MSE) = 20273.876 | bias = 0.322
#    - iteration: 3600 | loss (MSE) = 20271.498 | bias = 0.329
#    - iteration: 3700 | loss (MSE) = 20269.340 | bias = 0.336
#    - iteration: 3800 | loss (MSE) = 20267.364 | bias = 0.342
#    - iteration: 3900 | loss (MSE) = 20265.540 | bias = 0.349
#    - iteration: 4000 | loss (MSE) = 20263.843 | bias = 0.356
#    - iteration: 4100 | loss (MSE) = 20262.251 | bias = 0.363
#    - iteration: 4200 | loss (MSE) = 20260.747 | bias = 0.369
#    - iteration: 4300 | loss (MSE) = 20259.317 | bias = 0.376
#    - iteration: 4400 | loss (MSE) = 20257.948 | bias = 0.383
#    - iteration: 4500 | loss (MSE) = 20256.630 | bias = 0.389
#    - iteration: 4600 | loss (MSE) = 20255.355 | bias = 0.396
#    - iteration: 4700 | loss (MSE) = 20254.116 | bias = 0.403
#    - iteration: 4800 | loss (MSE) = 20252.907 | bias = 0.409
#    - iteration: 4900 | loss (MSE) = 20251.724 | bias = 0.416
#    - iteration: 5000 | loss (MSE) = 20250.562 | bias = 0.423
#    - iteration: 5100 | loss (MSE) = 20249.418 | bias = 0.429
#    - iteration: 5200 | loss (MSE) = 20248.290 | bias = 0.436
#    - iteration: 5300 | loss (MSE) = 20247.174 | bias = 0.443
#    - iteration: 5400 | loss (MSE) = 20246.069 | bias = 0.449
#    - iteration: 5500 | loss (MSE) = 20244.973 | bias = 0.456
#    - iteration: 5600 | loss (MSE) = 20243.885 | bias = 0.463
#    - iteration: 5700 | loss (MSE) = 20242.804 | bias = 0.469
#    - iteration: 5800 | loss (MSE) = 20241.728 | bias = 0.476
#    - iteration: 5900 | loss (MSE) = 20240.656 | bias = 0.482
#    - iteration: 6000 | loss (MSE) = 20239.589 | bias = 0.489
#    - iteration: 6100 | loss (MSE) = 20238.526 | bias = 0.496
#    - iteration: 6200 | loss (MSE) = 20237.465 | bias = 0.502
#    - iteration: 6300 | loss (MSE) = 20236.407 | bias = 0.509
#    - iteration: 6400 | loss (MSE) = 20235.351 | bias = 0.516
#    - iteration: 6500 | loss (MSE) = 20234.296 | bias = 0.522
#    - iteration: 6600 | loss (MSE) = 20233.244 | bias = 0.529
#    - iteration: 6700 | loss (MSE) = 20232.193 | bias = 0.536
#    - iteration: 6800 | loss (MSE) = 20231.143 | bias = 0.542
#    - iteration: 6900 | loss (MSE) = 20230.094 | bias = 0.549
#    - iteration: 7000 | loss (MSE) = 20229.046 | bias = 0.555
#    - iteration: 7100 | loss (MSE) = 20227.999 | bias = 0.562
#    - iteration: 7200 | loss (MSE) = 20226.952 | bias = 0.569
#    - iteration: 7300 | loss (MSE) = 20225.906 | bias = 0.575
#    - iteration: 7400 | loss (MSE) = 20224.861 | bias = 0.582
#    - iteration: 7500 | loss (MSE) = 20223.816 | bias = 0.588
#    - iteration: 7600 | loss (MSE) = 20222.772 | bias = 0.595
#    - iteration: 7700 | loss (MSE) = 20221.728 | bias = 0.602
#    - iteration: 7800 | loss (MSE) = 20220.684 | bias = 0.608
#    - iteration: 7900 | loss (MSE) = 20219.641 | bias = 0.615
#    - iteration: 8000 | loss (MSE) = 20218.598 | bias = 0.622
#    - iteration: 8100 | loss (MSE) = 20217.555 | bias = 0.628
#    - iteration: 8200 | loss (MSE) = 20216.512 | bias = 0.635
#    - iteration: 8300 | loss (MSE) = 20215.470 | bias = 0.641
#    - iteration: 8400 | loss (MSE) = 20214.428 | bias = 0.648
#    - iteration: 8500 | loss (MSE) = 20213.386 | bias = 0.655
#    - iteration: 8600 | loss (MSE) = 20212.345 | bias = 0.661
#    - iteration: 8700 | loss (MSE) = 20211.304 | bias = 0.668
#    - iteration: 8800 | loss (MSE) = 20210.262 | bias = 0.674
#    - iteration: 8900 | loss (MSE) = 20209.221 | bias = 0.681
#    - iteration: 9000 | loss (MSE) = 20208.180 | bias = 0.688
#    - iteration: 9100 | loss (MSE) = 20207.140 | bias = 0.694
#    - iteration: 9200 | loss (MSE) = 20206.099 | bias = 0.701
#    - iteration: 9300 | loss (MSE) = 20205.059 | bias = 0.708
#    - iteration: 9400 | loss (MSE) = 20204.019 | bias = 0.714
#    - iteration: 9500 | loss (MSE) = 20202.979 | bias = 0.721
#    - iteration: 9600 | loss (MSE) = 20201.939 | bias = 0.727
#    - iteration: 9700 | loss (MSE) = 20200.899 | bias = 0.734
#    - iteration: 9800 | loss (MSE) = 20199.860 | bias = 0.741
#    - iteration: 9900 | loss (MSE) = 20198.820 | bias = 0.747
# Treinamento Finalizado

# %%
# Explore more plots to analyze the predictions, e.g., predictions vs time, contribution of each feature to the predictions, etc.

# %% [markdown]
# > **Question:**
# >
# > Based on your visualizations, do you observe systematic deviations
# (for example curvature or clusters)?
# >
# > If systematic patterns exist, what do they suggest about the relationship between
# the predictors and the target?
# >
# > Does this visualization support or contradict the hypotheses you proposed earlier?

# %% [markdown]
# *YOUR ANSWER HERE*

# %% [markdown]
# ---
# #### **Residual Analysis**
# (1.0 points) As discussed above, a main assumption we have made is the nature of $\epsilon$ to
# be Gaussian.
#
# These error values are now computable by the difference between the ground-truth and
# the predicted values
#
# $$r_i = y - \hat{y} \sim \mathcal{N}(0, \sigma)$$
#
# Therefore, if our linear regression model is correct, we can observe normally
# distributed residuals across the dataset.
# One way of checking how normally is distributed our distribution is by a
# quantile–quantile (Q–Q) plot.
#
# This plot compares the empirical distribution of residuals with the theoretical quantiles of a reference distribution (usually the normal distribution).
#
# To do this, we sort the residuals, compute the theoretical quantiles and plot they along
# so each point (r_i, q_i) compares the observed residual and the quantile if the
# distribution were normally distributed.
#
# Similarly to the previous plot, if the points follow the line y=x, the quantiles
# are well aligned with the empirical distribution, suggesting a good fit.
# However, curvatures may represent skews in the distribution, usually indicating
# that the distribution is not normal.

# %%
def q_q_plot(y_true: NDArray[np.float64], y_pred: NDArray[np.float64]) -> None:
    residuals = y_true - y_pred

    sorted_residuals = np.sort(residuals)
    theoretical_quantiles = np.sort(np.random.normal(loc=0, scale=np.std(residuals), size=len(residuals)))

    plt.figure(figsize=(10, 6))
    plt.grid()
    plt.scatter(theoretical_quantiles, sorted_residuals, alpha=0.5, s=10, label='Residuals')
    plt.plot([theoretical_quantiles.min(), theoretical_quantiles.max()], [theoretical_quantiles.min(), theoretical_quantiles.max()], color='red', linestyle='--', label='Ideal Fit')
    plt.xlabel("Theoretical Quantiles")
    plt.ylabel("Ordered Residuals")
    plt.title("Q-Q Plot of Residuals")
    plt.legend()
    plt.show()

# %%
q_q_plot(y, y_pred)

# %% [markdown]
# > **Question:**
# >
# > Are the points approximately aligned along a straight line?
# >
# > What does this indicate about the Gaussian noise assumption used to derive
# the MSE objective?
# >
# > Based on the evidence from the metrics and plots,
# > is linear regression an appropriate model for this dataset?
# >
# > Justify your conclusion.

# %% [markdown]
# *YOUR ANSWER HERE*

# %% [markdown]
# ---
#
# ## **Polynomial Models**

# %% [markdown]
# Linear regression assumes that the relationship between the features and the
# target is linear.
# However, in many real-world situations the relationship between
# a variable and the output may be curved or more complex.
#
# For example, suppose that the number of bike rentals increases with temperature
# up to a comfortable level, but then decreases when the weather becomes too hot.
# A straight line would not be able to capture this behavior.
#
# One way to increase the flexibility of linear regression is to transform the
# input features.
# Instead of using raw variables $x_i$, we can include higher
# powers of it, creating new features such as $x_i^2$, $x_i \cdot x_j$, and so on.
#
# For instance, a quadratic model can be written as
#
# $$y \approx \beta_0 + \beta_1 x + \beta_2 x^2.$$
#
# Although this model is nonlinear with respect to the original variables,
# it is still **linear in the parameters** $\beta$.
# Because of this, the same training methods used for linear regression can still
# be applied.
#
# The effect is an increased set of possible models that can describe the relationship
# between $x$ and $y$ via parameters $\beta$.
#
# In practice, polynomial regression is implemented by **expanding the feature
# space**.
# For example, if the original input is $(x_1, x_2)$, apolynomial expansion of
# degree two could produce the new feature vector
#
# $$(x_1, x_2, x_1^2, x_2^2, x_1 x_2).$$
#
# The regression model is then applied to this expanded set of features.
# This transformation allows the model to capture nonlinear relationships while
# keeping the optimization problem simple.
#
# ### **Model Capacity and Overfitting**
#
# Increasing the polynomial degree increases the **capacity** of the model. A
# higher-degree polynomial can represent more complex relationships in the data.
#
# However, a model that is too flexible may start fitting the noise present in
# the training data instead of the underlying relationship. This phenomenon is
# called **overfitting**.
#
# As the polynomial degree increases:
#
# - The training error usually decreases.
# - The test error may start increasing after a certain point.
#
# This happens because the model becomes too specialized to the training dataset.
#
# ### **Implementation**
#
# (1.0 points) Implement the `polynomial_expansion` function that expands the input features
# to polynomial features of degree at most $d$.
#
# Instead of using only the original variables, now include polynomial terms with
# different degree values, for example, $d = 2, 3, \dots$.
# This makes the model more flexible and can represent non-linear relationships
# between the predictors and the target.
#
# Remember to test for different learning rates, similar to what was done previously.

# %%
def polynomial_expansion(X: NDArray[np.float64], d: int) -> NDArray[np.float64]:
    raise NotImplementedError(
        "Implement this function to perform polynomial expansion of the features up to degree d"
    )

# %%
# Implement and train the polynomial regression models here using the 
# polynomial_expansion function to transform the features before training the linear regression model.

# Experiment with different degrees and analyze the results to choose the best combination
# of learning rate and degree for the polynomial regression model.

# %% [markdown]
# > **Question:**
# >
# > How does the training error of the polynomial model compare with the
# training error of the linear regression model?
# >
# > Does this result indicate that it is better than the linear
# model for this problem?
# >
# > Which degree would you select to explore?

# %% [markdown]
# *YOUR ANSWER HERE*

# %% [markdown]
# ---
# ### **Visualizing Predictions**
#
# (1.5 points) Inspect the predicted vs observed plot, compare with the same plots used in the
# linear model, are they different?
#
# Explore how the results change and link them with training error in the polynomial
# model.

# %%
best_lr = 1 # Choose the best learning rate based on the previous graphs
best_degree = 100 # Choose the best degree based on experimentation with different degrees and analyzing the results

X_poly = polynomial_expansion(X, best_degree)

best_poly_model = LinearRegression(learning_rate=1, n_iterations=10000)
best_poly_model.fit(X_poly, y)
y_pred = best_poly_model.predict(X_poly)

pred_vs_true_plot(y, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[127], line 4
#       1 best_lr = 1 # Choose the best learning rate based on the previous graphs
#       2 best_degree = 100 # Choose the best degree based on experimentation with different degrees and analyzing the results
#       3
# ----> 4 X_poly = polynomial_expansion(X, best_degree)
#       5
#       6 best_poly_model = LinearRegression(learning_rate=1, n_iterations=10000)
#       7 best_poly_model.fit(X_poly, y)
#
# Cell In[125], line 2, in polynomial_expansion(X, d)
#       1 def polynomial_expansion(X: NDArray[np.float64], d: int) -> NDArray[np.float64]:
# ----> 2     raise NotImplementedError(
#       3         "Implement this function to perform polynomial expansion of the features up to degree d"
#       4     )
#
# NotImplementedError: Implement this function to perform polynomial expansion of the features up to degree d

# %%
q_q_plot(y, y_pred)

# %%
# Plot other visualizations too to better analyze the predictions.

# %% [markdown]
# > **Question:**
# >
# > Does the polynomial model appear to capture relationships that the linear model
# could not?
# >
# > Did this choice fixed the systematic deviations previously observed?

# %% [markdown]
# *YOUR ANSWER HERE*

# %% [markdown]
# ---
# ## **Count Data and Model Assumptions**

# %% [markdown]
# > **IMPORTANT:** This section is optional and will yield **additional 1.0 points**
# > to your assignment.
# > We reccomend you to finish the mandatory sections above before attempting to
# > switch to additional assumptions and model decisions this section introduces.
# >
# > Despite this section being optional, we strongly advise you on exploring
# > the following models, not only as an additional model to your toolbox, but
# > from the modeling perspective of statistical learning.
#
# \
# In the previous sections we used linear regression and polynomial models
# to predict the number of bike rentals.
# However, the target variable in this dataset has a particular characteristic,
# it represents a **count**.
#
# This is important because, when we were stating the assumptions in the linear model,
# we had no hard assumption on the target nature, it was a real number.
# In counting problems, the target is a positive integer number with specific
# characteristics that are ignored.
#
# Therefore, a possible direction of improvement is choosing the model that best
# aligns with our problem, exploiting the domain knowlegde we have to produce better
# estimators.
#
# In this section, we are going to use a new linear model with a different
# probabilistic assumption for the target variable.

# %% [markdown]
# ### **Poisson distribution**
#
# A common model for count data is the **Poisson distribution**.
# This distribution describes the probability of observing a number of events
# during a fixed interval.
#
# For example, the number of students achieving a low and high mark in an exam,
# the number of meteorites that strike Earth in a year.
#
# The Poisson distribution is parameterized by a rate parameter $\lambda > 0$,
# which represents the expected number of events in a time unit.
#
# The probability of observing a value $y$ is
#
# $$p(y \mid \lambda) = \frac{\lambda^y e^{-\lambda}}{y!}.$$
#
# In this model, both the mean and the variance are equal to $\lambda$.
# Therefore, when predicting, returning the expected count value $\hat{y}$ is
# equivalent to returning $\lambda$ itself.
#
# ### **Poisson Regression**
# Poisson regression is a special case of the Generalized Linear Models along with
# Linear and Logistic regression.
# The idea here is to model $\lambda$ as a function of the input $x$ and parameters
# $\beta$ and describe $p(y \mid x, \beta) = p(y \mid \lambda)$.
#
# Again, as a linear model, we want to relate the linear combination
# $\beta_0 + \beta_1 x_1 + \dots + \beta_n x_n$ to this new parameter $\lambda$,
# that is strictly positive.
#
# To make this to happen, we define a **link function** $g$ such that $g(\lambda)$
# can vary from -$\infty$ to $\infty$, thus allowing that
#
# $$g(\lambda) = \beta_0 + \beta_1 x_1 + \dots + \beta_n x_n,$$
# as $\beta$ and $x$ are unconstrained.
#
# A common link function used in Poisson regression is the $\log$, making
#
# $$\hat{y} = \lambda = \exp(\beta_0 + \beta_1 x_1 + \dots + \beta_n x_n),$$
# turning the previously unconstrained prediction in a strictly positive count
# parameter, and then addressing a probability using the Poisson distribution.
#
# #### **Implementation**
#
# (1.0 points) Derive the loss function of the Poisson Regression,
#
# $$-\log \mathcal{L}(\beta) = -\sum_{i=1}^n \log p(y^i \mid x^i, \beta),$$
# using the Poisson distribution instead of the Gaussian distribution for $p(y^i \mid x^i, \beta)$.
#
# **Hint:** You can ignore constant terms and scales in the objective function to
# obtain a MSE-like gradient.
#
# > **Question:**
# >
# > Is the negative log-likelihood the same?
# >
# > Is it equivalent to a Linear regressor predicting $\log y$ instead of $y$?

# %% [markdown]
# *YOUR ANSWER HERE*

# %% [markdown]
# ---
# Implement this regression using the same pattern as the `LinearRegression` and
# train a Poisson regression model using the same training dataset used
# previously, selecting appropriate learning rates.

# %%
class PoissonRegression:
    def __init__(
        self,
        learning_rate: float = 0.01,
        n_iterations: int = 1000,
    ) -> None:
        self.learning_rate = learning_rate
        self.n_iterations = n_iterations
        self.weights: NDArray[np.float64] | None = None
        self.bias: float | None = None

    def fit(self, X: NDArray[np.float64], y: NDArray[np.float64]) -> None:
        n_samples, n_features = X.shape
        weights = np.zeros(n_features)
        bias = 0.0

        raise NotImplementedError(
            "Implement this function to train the linear regression model using gradient descent"
        )
    
    def predict(self, X: NDArray[np.float64]) -> NDArray[np.float64]:
        assert self.weights is not None and self.bias is not None, "Model is not trained yet"

        raise NotImplementedError(
            "Implement this function to make predictions using the trained linear regression model"
        )

# %%
# Implement and train the poisson regression models here.

# %% [markdown]
# > **Question:**
# >
# > Compare the performance of the Poisson models with the Linear Regression model.
# > Even though both models rely on a linear combination of the features,
# > their predictions are not computed in the same way.
# >
# > $\hat{y}=x^T\beta$
# >
# > $\lambda=\exp(x^T\beta)$
# >
# > Are the predictive performances equivalent?
# > Which model appears to produce predictions that better match the data?
# >
# > Explain why two models that both use a linear predictor can still behave
# > very differently. Consider the distributional assumptions and the
# > transformation applied to the output.

# %% [markdown]
# *YOUR ANSWER HERE*

# %% [markdown]
# ---
# ### **Visualizing Predictions**
#
# Check how the predictions change when moving from the **Gaussian assumption**
# used in linear regression to the **Poisson assumption** used in Poisson regression.
#
# Plot the predicted values against the observed values and compare the
# distribution of points with the plots obtained previously.
#
# Pay attention to how the **shape of the point cloud** changes under the
# different modeling assumptions.

# %%
best_lr = 1 # Choose the best learning rate based on the previous graphs

best_poisson_model = PoissonRegression(learning_rate=best_lr, n_iterations=10000)
best_poisson_model.fit(X, y)
y_pred = best_poisson_model.predict(X)

pred_vs_true_plot(y, y_pred)

# %%
# Plot other visualizations too to better analyze the predictions.

# %% [markdown]
# > **Question:**
# >
# > Compare the prediction plots obtained with the **Linear**, **Polynomial**, and
# > **Poisson** models.
# >
# > - Does the Poisson model change the overall shape of the prediction cloud?
# > - Do the predictions appear more consistent with the count nature of the data?
# > - Are extreme values predicted differently?
# >
# > Based on the visualization, what differences arise from changing the
# > probabilistic assumption of the model?

# %% [markdown]
# *YOUR ANSWER HERE*

# %% [markdown]
# ---
# ### **Residual Diagnostics for Poisson Regression**
#
# In the previous sections we used a **Q–Q plot** to evaluate whether the
# residuals followed a **Normal distribution**. This diagnostic was meaningful
# because linear regression was derived under the assumption that the error term
# follows a Gaussian distribution,
#
# $$\epsilon \sim \mathcal{N}(0,\sigma^2).$$
#
# Under this assumption, if the model is well specified, the residual
#
# $$r_i = y_i - \hat{y}_i,$$
# should also resemble a Normal distribution.
#
# The Q–Q plot therefore allowed us to visually verify whether this assumption was
# reasonable.
# However, this reasoning no longer applies to **Poisson regression**, as the
# target $y$ now is assumed to be drawn from a Poisson distribution with
#
# $$y \sim \text{Poisson}(\lambda), \qquad \lambda = \exp(x^T\beta).$$
#
# Because of this, the residuals are **not expected to follow a Normal
# distribution**, even if the model is correct.
# A Q–Q plot comparing them to a Normal distribution therefore does not test a
# relevant assumption.

# %% [markdown]
# ---
# ### **Polynomial Poisson Regression**
#
# As we observed an increased performance by introducing polynomial
# features, allowing the model to capture nonlinear relationships between the
# predictors and the target.
# The same idea can be applied to **Poisson regression**.
#
# Instead of changing the probabilistic model, we only change the
# **feature representation**. The Poisson model still assumes that the
# expected count follows an exponential transformation of a linear
# predictor,
#
# $$\lambda = \exp(x^T\beta).$$
# with $x$ now containing polynomial terms.
#
# Continue exploring Poisson models with more complex relationships, find the best
# degrees and learning rates.

# %%
# Implement and train the polynomial poisson regression models here using the 
# polynomial_expansion function to transform the features before training the linear regression model.

# Experiment with different degrees and analyze the results to choose the best combination
# of learning rate and degree for the polynomial regression model.

# %%
best_lr = 1 # Choose the best learning rate based on the previous graphs
best_degree = 100 # Choose the best degree based on experimentation with different degrees and analyzing the results

X_poly = polynomial_expansion(X, best_degree)

best_poisson_poly_model = PoissonRegression(learning_rate=best_lr, n_iterations=10000)
best_poisson_poly_model.fit(X_poly, y)
y_pred = best_poisson_poly_model.predict(X_poly)

pred_vs_true_plot(y, y_pred)

# %% [markdown]
# > **Question:**
# >
# > Compare the residual structure of the **Poisson** and
# > **Polynomial Poisson** models.
# >
# > Was the improvement similar to the Linear Regression counterparts?
# > How are they different?

# %% [markdown]
# *YOUR ANSWER HERE*

# %% [markdown]
# ---
# ## **Final Model Comparison**

# %% [markdown]
# Until this point, all analysis and decisions were made using only the **training data**.
# The **test dataset** has remained untouched so that it can provide an unbiased
# evaluation of the final models.
#
# This is important in machine learning, as our job is not train a model that can
# copy the behavior in data, but to generalize to unseen observations.
# The decisions made to improve the performance based only on training data may or
# may not reflect in the test data, indicating a under or overfitting.
#
# (1.0 points) Before using the test dataset, look at all your decisions and assumptions done
# on each model and discuss them.
# In real life, this would be the last step before the deployment our models.
#
# > **Question:**
# >
# > Revisiting all the models you have trained, what are the main differences between them in performance and assumptions?
# >
# > If you could select only one, based on your analysis, which one would you choose and why?
# > Also discuss about its possible limitations, what it doesn't solve?
# >
# > How do you think it will perform on unseen data?

# %% [markdown]
# *YOUR ANSWER HERE*

# %% [markdown]
# ---
#
# (0.5 points) Now evaluate all trained models on the **test dataset** using the same metrics
# used previously.
# Compute the predictions and compare their performance.

# %%
# Comparison code here, make sure you have the final models

# %%
X_test, y_test = preprocess_data(test_df)

# You can create plots comparing the predictions of the different models, e.g., predicted vs true values for each model, residual plots, etc.
# Measure the performance of each model using the implemented metrics and compare them in a table or bar plot.
# Feel free to explore other ways to compare the models and analyze their predictions.

# %% [markdown]
# > **Question:**
# >
# > Compare the performance of all models on the **test dataset**.
# >
# > Are the differences between the models large or small?
# >
# > Does the test behave the same as the train results?
# > Did you make the right choices when you selected the "best" model based on the training data?
# >
# > Finally, make hypothesis on the whole result, why the test behave differently
# from the train? What different decisions would you have made if you had access to the
# test data?

# %% [markdown]
# *YOUR ANSWER HERE*

# %% [markdown]
# ---
# ## **Assignment submission**

# %% [markdown]
# This notebook must be filled with your solution and submitted on the Assignment's entry at our Google Classroom page.
# Before submitting, make sure that
# - Your notebook runs end-to-end without errors.
# - All the plots are included in the notebook.
# - The notebook must be self-contained and there is no external dependency.
#
# **Important: Only one member of the group should submit the solution.**
#
# ### **Policy for late submissions**
#
# You are NOT encouraged to submit the solution after the deadline; however, in this case, the following penalties hold:
#
# * 25% of the grade for 1-day late submission;
# * 50% of the grade for 2-day late submission;
# * 75% of the grade for 3-day late submission.
